# %%
import os
import re
import glob 
import matplotlib.pyplot as plt
import numpy as np
from os.path import basename
#import audiosegment
from multiprocessing import Pool, freeze_support

import sys
import numpy

import librosa
import pickle
import acousticFeatures

from typing import Dict, Tuple, List

#Constant
EMOTION_ANNOTATORS = {'anger': 0, 'happiness' : 1, 'sadness' : 2, 'neutral' : 3, 'frustration' : 4, 'excited': 5,
           'fear' : 6,'surprise' : 7,'disgust' : 8, 'other' : 9}

EMOTION = {'ang': 0, 'hap' : 1, 'sad' : 2, 'neu' : 3, 'fru' : 4, 'exc': 5,
           'fea' : 6,'sur' : 7,'dis' : 8, 'oth' : 9, 'xxx':10}

METHOD = {'audio_feature':0, 'LSTM':1}

#Method for classification
method = METHOD['audio_feature']


isRawDataProcessed = False

#Development mode. Only run with small data.
dev = False

onlyAcoustic = True


#Define class
class Input:
    ##spectral, prosody, erergy are dict type
    def __init__(self, spectral=None, prosody=None, energy=None, spectrogram=None, acoustic_features=None):
        self.spectral = spectral
        self.prosody = prosody
        self.energy = energy
        self.spectrogram = spectrogram
        self.onlyAcoustic = onlyAcoustic
        self.acoustic_features = acoustic_features
        
    def print(self):
        print("spectral  features: ", spectral)
        print("prosody features: ", prosody)
        print("energy: ", energy)
        print("spectrogram: ", spectrogram)
        
    def input2Vec(self, onlySpectrogram, onlyAcoustic):
        
        if (onlySpectrogram ==  False):
            features = []
            if (onlyAcoustic == False):
                s = list(self.spectral.values())
                p = list(self.prosody.values())
                e = list(self.energy.values())
                [features.extend(x) for x in [s, p, e]]
            else:
                features = self.acoustic_features
               # print("fea:", features)
            return features
        else :
            return self.spectrogram
    
class Output:
    def __init__(self, duration, code, category_origin, category_evaluation, attribute, ):
        self.duration = duration
        self.code = code
        self.category_origin = category_origin
        self.category_evaluation = category_evaluation
        self.attribute = attribute
        
    def isConsitent(self):
        counts = np.unique(self.category_evaluation , return_counts=True)[1]
        consitent_degree = np.max(counts)/np.sum(counts)
        print(consitent_degree)
        if(consitent_degree >= 0.7):
            return True
        return False

    def output2Vec(self):
        return self.attribute
    
    
    
#Functions for get features from audio file
def amp2Db(samples):
    dbs = []
    for  x in samples:
        if x < 0:
            v = - dspUtil.rmsToDb(np.abs(x))
        elif x == 0:
            v = 0
        else :
            v = dspUtil.rmsToDb(np.abs(x))
        dbs.append(v)
    return dbs

def getF0Features(file):
    features = {}
    sound = audiosegment.from_file(file)
    voiced = sound.filter_silence(duration_s=0.2)
    frame_rate = sound.frame_rate
    frames = sound.dice(0.032)

    f0s = []
    for f in frames:
        f0 = dspUtil.calculateF0once(amp2Db(f.get_array_of_samples()), frame_rate)
        if(f0 != 0):
            f0s.append(f0)
    
    features['f0_min'] = np.min(f0s)
    features['f0_max'] = np.max(f0s)
    features['f0_range'] = np.max(f0s) - np.min(f0s)
    features['f0_mean'] = np.mean(f0s)
    features['f0_median'] = np.median(f0s)
    features['f0_25th'] = np.percentile(f0s, 25)
    features['f0_75th'] = np.percentile(f0s, 75)
    features['f0_std'] = np.std(f0s)
    
  
    return features

def getEnergyFeatures(file):
    features = {}
    sound = audiosegment.from_file(file)
    voiced = sound.filter_silence(duration_s=0.2)
    samples = voiced.get_array_of_samples()
    frame_rate = sound.frame_rate
    frames = sound.dice(0.032)
    
    e = []
    for f in frames:
        e.append(np.abs(f.max_dBFS))
    
    
    features['energy_min'] = np.min(e)
    features['energy_max'] = np.max(e)
    features['energy_range'] = np.max(e) - np.min(e)
    features['energy_mean'] = np.mean(e)
    features['energy_median'] = np.median(e)
    features['energy_25th'] = np.percentile(e, 25)
    features['energy_75th'] = np.percentile(e, 75)
    features['energy_std'] = np.std(e)   

    return features
    
def audio2Features(file):
    spectral = {}
    prosody = {}
    energy = {}
    try:
        if (onlyAcoustic == False):
            prosody = getF0Features(file)
            energy = getEnergyFeatures(file)
            y, sr = librosa.load(file)
            spectrogram = librosa.stft(y)
            spectrogram = np.abs(spectrogram)
            #To be continued....
            return Input(spectral, prosody, energy, spectrogram)
        else :
            acoustic_features = acousticFeatures.getAllFeatures(file)
            return Input(acoustic_features = acoustic_features)
    except Exception as e:
        print(e)
        
        
#Function for getting input vector and corresponding output      
def parallel_task(d0, d1, d2):
    print("task...")
    # Each input diectory contains many file
    # This fucntion will walk through all valid 'wav'files in this directory and get features like engergy, frequency...
    
    def get_transcription(file: str) -> Dict[str, str] :
        """ Get all transriptions in file

            :param file: It is the path of the file
            :return: Dict. Keys are name of audio files. Values are their transcrips
        """
        result = {} # Dict containing the result 
        with open(file) as f:
            for line in f:
                #print("Orogin line:", line)
                parts = line.split(' ', maxsplit=2) # Example of one line in file: Name_file [t1-t2]: Transcript.
                try:
                    result[parts[0]] = parts[2]
                except:
                    print("Error caused by: ", parts)
                    print("In file:", file)
                    result[parts[0]] = ""

        return result
    
    
    def parseInput(dir):
        dicts = {} 
        for f in os.listdir(dir):
            if not f.startswith(".") and os.path.splitext(f)[1] == ".wav":
                dicts[os.path.splitext(f)[0]] = audio2Features(dir + "/" + f)


        return dicts
    
    # Each output file contains label of many diffrent 'wav' file.
    # This function will parse content of text file using 'regrex'. Then turn it into label
    def parseOutput(file):
        dict_namefile_output = {}
        # Open file to get all contents excepts the first line.
        f = open(file, 'r')
        content = ""
        index = 0
        for line in f:
            index = index + 1
            if index == 1:
                continue
            content  = content + line

        # Find all matched patterns in the content
        ps = re.findall(r'\[.*?\)\n\n', content, re.DOTALL)

        # Parse each matched pattern into  'Output' object
        try:
            for p in ps:
                ls = p.split("\n")
                ls = list(filter(lambda x: len(x) > 0 ,ls))

                # Split elements of the first line which looks like : 
                # [147.0300 - 151.7101]	Ses01F_impro02_M012	neu	[2.5000, 2.0000, 2.0000]
                ele_line0 = re.search(r'(\[.*?\])(\s)(.*?)(\s)(.*?)(\s)(\[.*?\])', ls[0]).groups()

                # Split time components which looks like:
                # [147.0300 - 151.7101]
                time_dur = ele_line0[0]
                ele_time_dur = re.findall(r"[-+]?\d*\.\d+|\d+", time_dur)
                ele_time_dur = [float(x) for x in ele_time_dur]

                # Get code and category_origin which looks like:
                # Code: Ses01F_impro02_M012
                # Category_origin: neu
                code = ele_line0[2]
                category_origin = ele_line0[4]

                # Split attribute components which looks like:
                # [2.5000, 2.0000, 2.0000]
                attribute = ele_line0[6]
                ele_attribute = re.findall(r"[-+]?\d*\.\d+|\d+", attribute)
                ele_attribute = [float(x) for x in ele_attribute]

                # Get categorial_evaluation:
                lines_categorical = list(filter(lambda x : x[0] == 'C', ls))
                rex = re.compile(r'C.*?:(\s)(.*?)(\s)\(.*?\)')

                category_evaluation = []
                for l in lines_categorical:
                    elements = rex.search(l).groups()
                    cat = elements[1]
                    cat = cat.split(";")
                    cat = map(lambda x: x.lstrip(), cat)
                    cat = list(filter(lambda x: len(x)>0, cat))
                    category_evaluation.extend(cat)


                # Make list distinct
                category_evaluation = np.array(category_evaluation)
                #category_evaluation = list(set(category_evaluation))
                
                

                # Make dict {name_file : parsed_output}
                dict_namefile_output[code] = Output(ele_time_dur, code, category_origin, category_evaluation, ele_attribute)
            return dict_namefile_output
        except Exception as e:
            print(e)


    ### Parse input and output files and get input and output as vector
    dicts_in = parseInput(d0)
    dicts_out = parseOutput(d1)
    dicts_transcript = get_transcription(d2)
    in_out = []
    
    keys = list(dicts_in.keys())
    for key in keys:
           
        value = dicts_in[key].input2Vec(onlySpectrogram=False, onlyAcoustic=True)
        if(value.all() != None ):
            in_out.append((value, dicts_out[key].output2Vec(), dicts_transcript[key]))
    return in_out
    
    
def createInput_Output():
    ### Get directories of input and output
    DATA_DIR = "auditary_emotion_recognition/IEMOCAP_full_release"
    NUM_SESSION = 5
    input_output = []
    for i in range (1, NUM_SESSION + 1):
        name_session = "Session" + str(i)
        root_dir_of_wav = DATA_DIR + "/" + name_session + "/sentences" + "/wav"
        root_dir_of_labels = DATA_DIR + "/" + name_session + "/dialog" + "/EmoEvaluation"
        root_dir_of_transcripts = DATA_DIR + "/" + name_session + "/dialog" + "/transcriptions"

        for x in os.walk(root_dir_of_wav):
            if(x[0] == root_dir_of_wav):
                dirs_of_wav = x[1]
                index = -1
            else:
                index = index + 1
                input_output.append((x[0], 
                                     root_dir_of_labels + "/" + dirs_of_wav[index] + ".txt",
                                     root_dir_of_transcripts + "/" + dirs_of_wav[index] + ".txt"
                                   ))
                
    
    ds = input_output
    in_out = []
    input = []
    out = []
    transcripts = []
    
    # Multi processing
    with Pool(processes=8) as pool:
         in_out = pool.starmap(parallel_task, ds)
   
    r = []
    for e in in_out:
        r = r + e
    
    input = [x[0] for x in r]
    out = [x[1] for x in r]
    transcripts = [x[2] for x in r]
    print("Finished creating input output into txt file")
    print("len input and output:", len(input), ", ", len(out))
    return (input, out, transcripts)

 


#If have not processed data yet then process, otherwise loading data from file.
if __name__ == '__main__':
   # multiprocessing.set_start_method('folk')
    print("hello")
    freeze_support()
    if isRawDataProcessed == False:

        ##Get input, normalize input, get output
        input, output, transcript = createInput_Output()

        transcript = np.array(transcript)
        output = np.array(output)

        if(method == METHOD['audio_feature']):
            input = np.array(input)
           # input = input / input.max(axis=0)
            filehandlerInput = open('processed-data/input_VAD.obj', 'wb')
            filehandlerOutput = open('processed-data/output_VAD.obj', 'wb')
            filehandlerTranscript = open('processed-data/transcript_VAD.obj', 'wb')


        pickle.dump(input, filehandlerInput)
        pickle.dump(output, filehandlerOutput)
        pickle.dump(transcript, filehandlerTranscript)

        print("Finish write processed data (input, output) to file!!!")
# Out:
# hello
# task...
# task...
# task...
# task...
# task...
# task...
# task...
# task...
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session1/sentences/wav/Ses01M_impro06/Ses01M_impro06_M029.wav
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session1/sentences/wav/Ses01M_script01_2/Ses01M_script01_2_M011.wav
# /home/vuthede/.local/lib64/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /home/vuthede/.local/lib64/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /home/vuthede/.local/lib64/python3.6/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /home/vuthede/.local/lib64/python3.6/site-packages/numpy/lib/function_base.py:4291: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# Orogin line: Ses01F_impro01_F000 [006.2901-008.2357]: Excuse me.
#
# Orogin line: Ses01F_impro01_M000 [007.5712-010.4750]: Do you have your forms?
#
# Orogin line: Ses01F_impro01_F001 [010.0100-011.3925]: Yeah.
#
# Orogin line: Ses01F_impro01_M001 [010.9266-014.6649]: Let me see them.
#
# Orogin line: Ses01F_impro01_F002 [014.8872-018.0175]: Is there a problem?
#
# Orogin line: Ses01F_impro01_M002 [016.8352-019.7175]: Who told you to get in this line?
#
# Orogin line: Ses01F_impro01_F003 [019.2900-020.7875]: You did.
#
# Orogin line: Ses01F_impro01_F004 [021.3257-024.7400]: You were standing at the beginning and you directed me.
#
# Orogin line: Ses01F_impro01_M003 [023.4700-028.0300]: Okay. But I didn't tell you to get in this line if you are filling out this particular form.
#
# Orogin line: Ses01F_impro01_F005 [027.4600-031.4900]: Well what's the problem?  Let me change it.
#
# Orogin line: Ses01F_impro01_M004 [028.3950-031.2117]: This form is a Z.X.four.
#
# Orogin line: Ses01F_impro01_M005 [031.2660-039.3875]: You can't--  This is not the line for Z.X.four.  If you're going to fill out the Z.X.four, you need to have a different form of ID.
#
# Orogin line: Ses01F_impro01_F006 [038.9650-043.5900]: What?  I'm getting an ID.  This is why I'm here.  My wallet was stolen.
#
# Orogin line: Ses01F_impro01_M006 [041.2300-046.9800]: No. I need another set of ID to prove this is actually you.
#
# Orogin line: Ses01F_impro01_F007 [046.5800-052.1900]: How am I supposed to get an ID without an ID?  How does a person get an ID in the first place?
#
# Orogin line: Ses01F_impro01_M007 [051.4000-057.6400]: I don't know.  But I need an ID to pass this form along.  I can't just send it along without an ID.
#
# Orogin line: Ses01F_impro01_F008 [056.1600-058.8225]: I'm here to get an ID.
#
# Orogin line: Ses01F_impro01_M008 [058.1800-062.5900]: No.  I need another ID, a separate one.
#
# Orogin line: Ses01F_impro01_F009 [061.8700-065.9700]: Like what?  Like a birth certificate?
#
# Orogin line: Ses01F_impro01_M009 [065.5100-073.0000]: A birth certificate, a passport...a student ID; didn't you go to school?  Anything?
#
# Orogin line: Ses01F_impro01_F010 [066.4200-069.3400]: Who the hell has a birth certificate?
#
# Orogin line: Ses01F_impro01_F011 [072.4500-082.2600]: Yes but my wallet was stolen, I don't have anything.  I don't have any credit cards, I don't have my ID.  Don't you have things on file here?
#
# Orogin line: Ses01F_impro01_M010 [081.5900-086.0300]: Yeah.  We keep it on file, but we need an ID to access that file.
#
# Orogin line: Ses01F_impro01_F012 [085.2700-088.0200]: That's out of control.
#
# Orogin line: Ses01F_impro01_M011 [087.1500-094.3900]: I don't understand why this is so complicated for people when they get here.  It's just a simple form.  I just need an ID.
#
# Orogin line: Ses01F_impro01_F013 [093.6700-097.0218]: How long have you been working here?
#
# Orogin line: Ses01F_impro01_M012 [095.8600-098.6800]: Actually too long.
#
# Orogin line: Ses01F_impro01_F014 [097.8900-102.9600]: Clearly.  You know, do you have like a supervisor or something?
#
# Orogin line: Ses01F_impro01_M013 [101.8400-107.8700]: Yeah.  Do you want to see my supervisor?  Huh? Yeah.  Do you want to see my supervisor?  Fine.  I'll be right back.
#
# Orogin line: Ses01F_impro01_F015 [103.9700-106.7100]: That would - I would appreciate that.  Yeah.
#
# task...
# Orogin line: Ses01M_script01_2_F000 [005.3913-008.2350]: Why did he invite her here?
#
# Orogin line: Ses01M_script01_2_M000 [008.4194-012.9200]: Well, maybe he wanted see her.
#
# Orogin line: Ses01M_script01_2_F001 [012.7400-017.2800]: It's been three and a half years.  Why all of a sudden?
#
# Orogin line: Ses01M_script01_2_M001 [018.1900-025.3600]: Well uh, He grew up next door to the girl, why wouldn't he want to see her?
#
# Orogin line: Ses01M_script01_2_M002 [026.5500-032.1900]: Don't look at me like that.  He didn't tell me anything he told you.
#
# Orogin line: Ses01M_script01_2_F002 [032.6300-035.3425]: He's not going to marry her.
#
# Orogin line: Ses01M_script01_2_M003 [034.7100-037.2100]: How do you know he's even thinking about it?
#
# Orogin line: Ses01M_script01_2_F003 [036.7600-039.4800]: it's got that about it.
#
# Orogin line: Ses01M_script01_2_M004 [039.1700-041.6900]: Oh so what?
#
# Orogin line: Ses01M_script01_2_F004 [041.1800-044.7000]: What is going on here, Joe?
#
# Orogin line: Ses01M_script01_2_M005 [044.6700-048.3700]: Okay, now listen, kids...
#
# Orogin line: Ses01M_script01_2_F005 [047.6200-056.0600]: The girl is not Larry's.  If the girl is Larry's girl she's not his she know she's not.
#
# Orogin line: Ses01M_script01_2_M006 [063.5200-065.2800]: Listen. Line. You can't read her mind.
#
# Orogin line: Ses01M_script01_2_F006 [064.4200-072.3600]: Then why is she still single?  New York is full of men probably a hundred people told her she is crazy but she is waited.
#
# Orogin line: Ses01M_script01_2_M007 [071.8800-074.4000]: And how do you know why she's waited.
#
# Orogin line: Ses01M_script01_2_F007 [074.0100-086.7700]: Because she knows what I know that's why.  She's faithful as a rock. in my darkest moments I think of her waiting and I know that I'm right.
#
# Orogin line: Ses01M_script01_2_M008 [087.5300-093.4400]: Okay, look it's a beautiful day.  Why are we arguing?
#
# Orogin line: Ses01M_script01_2_F008 [092.8300-103.0000]: Nobody in this house dares take away her faith Joe.  Her- strangers might but not her father, not her brother.
#
# Orogin line: Ses01M_script01_2_M009 [102.6100-106.8600]: What do you want me to do?  What do you want?
#
# Orogin line: Ses01M_script01_2_F009 [104.7050-118.3200]: I want you to---act like he is coming back.  Don't think I haven't noticed you, both of you since Chris invited her here.  I won't stand for any nonsense.
#
# Orogin line: Ses01M_script01_2_M010 [119.2100-121.2425]: Kate...
#
# Orogin line: Ses01M_script01_2_F010 [120.9400-124.3900]: Because if he's not coming back then I'll kill myself.
#
# Orogin line: Ses01M_script01_2_M011 [124.2883-125.3375]: [BREATHING]
#
# Orogin line: Ses01M_script01_2_F011 [124.9800-135.2991]: Oh, laugh at me, laugh all you like but why does this happen to very night she comes back?  She goes to sleep in his room and his memorial breaks in pieces.  Look at it, Joe look.
#
# Orogin line: Ses01M_script01_2_M012 [134.6900-137.0700]: All right, calm yourself.
#
# Orogin line: Ses01M_script01_2_F012 [136.6100-145.6000]: Believe with me Joe, you got to believe. Only last week a boy came back missing longer then Larry you read it yourself.
#
# Orogin line: Ses01M_script01_2_M013 [138.5700-142.3975]: Okay, calm yourself. Alright.
#
# Orogin line: Ses01M_script01_2_M014 [144.4400-146.7900]: calm yourself.
#
# Orogin line: Ses01M_script01_2_F013 [145.6400-150.2900]: You above all have got to believe. Just don't stop believing.
#
# Orogin line: Ses01M_script01_2_M015 [147.5375-152.1200]: What does that mean? Me above all? What does that mean?
#
# Orogin line: Ses01M_script01_2_M016 [152.6600-157.8900]: Look at you. You're shaking.
#
# Orogin line: Ses01M_script01_2_F014 [159.3000-161.8600]: I can't help it.
#
# Orogin line: Ses01M_script01_2_M017 [163.3800-167.4300]: What the hell do you want from me, Kate?
#
# task...
# Orogin line: Ses01M_impro06_F000 [010.0955-012.6800]: You okay?
#
# Orogin line: Ses01M_impro06_M000 [012.4633-016.5100]: Yeah, I'm just-- yeah
#
# Orogin line: Ses01M_impro06_M001 [019.1808-022.8900]: Just kind of feel numb, you know.
#
# Orogin line: Ses01M_impro06_F001 [023.2600-026.3875]: What's happened?
#
# Orogin line: Ses01M_impro06_M002 [025.7888-030.0906]: You didn't even hear?
#
# Orogin line: Ses01M_impro06_M003 [031.7600-035.3600]: [BREATHING] Umm.
#
# Orogin line: Ses01M_impro06_M004 [036.1100-040.0000]: God I've told this story so many times. Umm.
#
# Orogin line: Ses01M_impro06_F002 [039.4300-041.7500]: You don't have to if you don't want to.
#
# Orogin line: Ses01M_impro06_M005 [041.2200-044.6825]: I just...I just basically lost someone that was really close to me.
#
# Orogin line: Ses01M_impro06_M006 [046.4100-061.9900]: And I've kind of been dealing with all of the...the stuff, you know the hospital and people work because...
#
# Orogin line: Ses01M_impro06_F003 [061.8600-064.6500]: I'm sorry to hear that.
#
# Orogin line: Ses01M_impro06_M007 [063.6300-067.6300]: He kind of didn't have anyone to take care of that for him, so--
# Orogin line: Ses01M_impro06_F004 [067.2770-070.1200]: You've been taking care of it all?
#
# Orogin line: M: Yeah.
#
# Error caused by:  ['M:', 'Yeah.\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro06.txt
# Orogin line: Ses01M_impro06_F005 [070.2050-072.2704]: Oh Jesus.
#
# Orogin line: Ses01M_impro06_M008 [071.7900-076.0581]: It's just really...really messed up.
#
# Orogin line: Ses01M_impro06_F006 [076.5016-079.0300]: He sick for awhile?
#
# Orogin line: Ses01M_impro06_M009 [079.2956-082.6661]: No.
#
# Orogin line: Ses01M_impro06_M010 [083.7526-087.2340]: Just like it.
#
# Orogin line: Ses01M_impro06_F007 [087.2562-089.4700]: Was it an accident?
#
# Orogin line: Ses01M_impro06_M011 [089.2950-095.8900]: No, I mean it just came on really quick, you know I mean it was a [GARBAGE] it was a sickness but it just --
#
# Orogin line: Ses01M_impro06_F008 [094.6200-096.5200]: how was sick?
#
# Orogin line: Ses01M_impro06_M012 [096.5029-097.9600]: What?
#
# Orogin line: Ses01M_impro06_F009 [097.4500-101.4200]: Well, I'm confused.  He was sick or it was an accident?
#
# Orogin line: Ses01M_impro06_M013 [100.6075-105.7400]: He was sick. He got sick. He got sick but it happened really, really fast, you know.
#
# Orogin line: Ses01M_impro06_F010 [101.5000-105.8675]: Oh. Really fast? Oh.
#
# Orogin line: Ses01M_impro06_M014 [105.8400-109.1600]: It was kind of like boom... done
#
# Orogin line: Ses01M_impro06_F011 [107.0200-108.5600]: Yeah.
#
# Orogin line: Ses01M_impro06_M015 [109.5900-114.6100]: It's just really weird because he was really young you know and it kind of like...
#
# Orogin line: Ses01M_impro06_F012 [112.6150-113.9775]: Yeah.
#
# Orogin line: Ses01M_impro06_M016 [115.9875-118.2500]: --it just kind of freaks you out.
#
# Orogin line: Ses01M_impro06_F013 [117.8500-120.8000]: Totally, yeah.
#
# Orogin line: Ses01M_impro06_M017 [123.1500-146.8900]: So weird you know that like one days it's like you know sounds so stupid but like one day someone's here. And like next day you know they're not here and it just kind of makes you like think about like life and mortality and like that kind of stuff.  You just like used to take for granted--you know.
#
# Orogin line: Ses01M_impro06_F014 [131.1825-132.5550]: Mmhmm.
#
# Orogin line: Ses01M_impro06_F015 [143.9425-145.1600]: Lock
#
# Orogin line: Ses01M_impro06_F016 [145.9400-147.7800]: Mmhmm.
#
# Orogin line: Ses01M_impro06_F017 [148.2650-150.7100]: The plans you make [GARBAGE].
#
# Orogin line: Ses01M_impro06_M018 [150.0500-153.9300]: Exactly, you know, and like he had so many plans and he was going to do...
#
# Orogin line: Ses01M_impro06_F018 [157.2300-159.5700]: It leaves a hole for you too.
#
# Orogin line: F: Mmhmm.
#
# Error caused by:  ['F:', 'Mmhmm.\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro06.txt
# Orogin line: Ses01M_impro06_M019 [154.5500-157.4000]: so many things, you know?
#
# Orogin line: Ses01M_impro06_F019 [159.7500-163.9425]: It leaves a hole for you too, in your plans together.
#
# Orogin line: Ses01M_impro06_M020 [159.3500-160.7400]: What?
#
# Orogin line: Ses01M_impro06_M021 [163.7300-165.8600]: Yeah.
#
# Orogin line: Ses01M_impro06_F020 [178.3706-181.4300]: It gets better.
#
# Orogin line: Ses01M_impro06_M022 [181.8077-184.8600]: He was a really, really good guy.
#
# Orogin line: Ses01M_impro06_F021 [184.2600-186.2647]: Mmhmm.
#
# Orogin line: Ses01M_impro06_M023 [186.5973-189.5500]: A lot of people loved him.
#
# Orogin line: Ses01M_impro06_F022 [188.9700-190.9200]: MMhmm.
#
# Orogin line: Ses01M_impro06_M024 [193.1300-197.5100]: You know, it's like affecting a lot of people it's not just me, you know?
#
# Orogin line: Ses01M_impro06_F023 [197.0600-199.0500]: Mmhmm.
#
# Orogin line: Ses01M_impro06_F024 [200.3676-203.1600]: How long did you know each other?
#
# Orogin line: Ses01M_impro06_M025 [202.5100-203.8500]: Umm...
#
# Orogin line: Ses01M_impro06_M026 [205.6500-208.5721]: For like eight years.
#
# Orogin line: Ses01M_impro06_F025 [208.8826-210.7397]: That's a long time.
#
# Orogin line: Ses01M_impro06_M027 [210.2100-212.2200]: Yeah.
#
# Orogin line: Ses01M_impro06_F026 [214.6701-217.6415]: It's good that you were there.
#
# Orogin line: Ses01M_impro06_M028 [217.5175-221.8768]: Yeah, I'm glad I was there. Glad I- glad I got to be there.
#
# Orogin line: Ses01M_impro06_M029 [225.3200-227.5100]: So weird,
#
# Orogin line: Ses01M_impro06_F027 [233.0200-235.1300]: Yeah.
#
# Orogin line: Ses01M_impro06_M030 [227.5400-234.2600]: like I can't...it's like you know it's like "pinch me" it's like I can't believe like I'm dealing with this, you know.
#
# Orogin line: Ses01M_impro06_F028 [239.1062-242.6985]: Are there things you wish you'd done differently?
#
# task...
# Orogin line: Ses02M_impro07_M000 [003.3437-008.7809]: [BREATHING] So, you know I've been hearing back from some colleges.
#
# Orogin line: Ses02M_impro07_F000 [008.4007-010.5030]: Oh, yeah? Have you gotten letters yet?
#
# Orogin line: Ses02M_impro07_M001 [010.3086-013.9686]: Yeah. And guess who accepted me?
#
# Orogin line: F: And?
#
# Error caused by:  ['F:', 'And?\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session2/dialog/transcriptions/Ses02M_impro07.txt
# Orogin line: Ses02M_impro07_F001 [013.6194-017.8381]: Um, I don't know, where?
#
# Orogin line: Ses02M_impro07_M002 [017.5987-019.0925]: U.S.C..
#
# Orogin line: Ses02M_impro07_F002 [018.7267-022.6857]: Oh, U.S.C.? Oh my Gosh, that's awesome, that was your top choice, right?
#
# Orogin line: Ses02M_impro07_F003 [022.7069-025.1307]: Oh my Gosh, that's so cool.
#
# Orogin line: Ses02M_impro07_M003 [022.4553-024.5566]: Yeah, oh. I - You have no-
#
# Orogin line: Ses02M_impro07_M004 [025.2022-029.6828]: God, I-I got this big packet you know, in the mail and it's like-
#
# Orogin line: Ses02M_impro07_M005 [030.1215-038.6833]: yes, this is [LAUGHTER], it says U.S.C., like registrar, I mean like, I got-I got some like little letters before you know, it's like oh rejection
#
# Orogin line: Ses02M_impro07_F004 [031.0413-033.0824]: [LAUGHTER] It's gotta be it, like-
#
# Orogin line: Ses02M_impro07_F005 [034.8528-036.7393]: Oh my Gosh, that's so cool.
#
# Orogin line: Ses02M_impro07_M006 [038.7046-041.1736]: but big packet, big packet is nice
#
# Orogin line: Ses02M_impro07_F006 [039.6095-041.8900]: big packet is gotta be the real thing. yeah
#
# Orogin line: Ses02M_impro07_M007 [041.2070-046.0942]: So it's like, yes, rip it open and there it is big - oh, yes.
#
# Orogin line: Ses02M_impro07_F007 [043.1601-050.6653]: Oh my Gosh. I thought there was like, maybe going to be some, like I don't know if you are going to get in or not, so I'm really glad that you did.
#
# Orogin line: Ses02M_impro07_F008 [050.6866-052.3900]: That's so cool.
#
# Orogin line: Ses02M_impro07_M008 [050.8832-052.0800]: Yeah. I know, I know.
#
# Orogin line: Ses02M_impro07_M009 [052.0900-058.0000]: it was you know I wasn't too sure I mean you know it was kind of last minute for like the application
#
# Orogin line: Ses02M_impro07_M010 [058.0100-059.4500]: and everything like but
#
# Orogin line: Ses02M_impro07_F009 [057.9792-059.3824]: Yeah, totally.
#
# Orogin line: Ses02M_impro07_M011 [059.4600-061.2200]: it was good, yeah. I mean-
#
# Orogin line: Ses02M_impro07_F010 [060.2966-064.0030]: So you're going to be right here in Los Angeles; that is so cool.
#
# Orogin line: Ses02M_impro07_M012 [061.8100-069.3600]: I know, I know, yea. It'll be interesting you know, I've never -- I mean getting out of Vegas and everything but LA
#
# Orogin line: Ses02M_impro07_M013 [069.3700-071.0000]: I'm looking forward to it.
#
# Orogin line: Ses02M_impro07_F011 [069.3500-070.9600]: So can we hang out?
#
# Orogin line: Ses02M_impro07_M014 [071.0100-074.2000]: Hey, yes, you know that's - that's what I'm coming for.
#
# Orogin line: Ses02M_impro07_F012 [072.3600-073.6300]: Yay.
#
# Orogin line: Ses02M_impro07_M015 [074.2100-077.7582]: You're half the reason I'm going. [LAUGHTER]
#
# Orogin line: Ses02M_impro07_F013 [075.3283-077.7400]: Oh, yay. Thank you. [LAUGHTER].
#
# Orogin line: Ses02M_impro07_F014 [077.7500-081.2389]: No but that's an awesome school. That's so cool.
#
# Orogin line: Ses02M_impro07_M016 [079.2500-085.7800]: I know ahh- yeah-, I'm definitely looking forward to it, and I mean they had a great football season last year
# Orogin line: Ses02M_impro07_F015 [085.2147-086.8093]: Oh, totally totally.
#
# Orogin line: Ses02M_impro07_M017 [085.7900-089.2000]: You know what I mean, I bet the home games, are just like nuts you know.
#
# Orogin line: Ses02M_impro07_F016 [087.1070-089.1500]: you get to like be a part of that.
#
# Orogin line: Ses02M_impro07_F017 [089.1600-093.4853]: Like you get to be a part of that. Like the, like the- Like a cult.
#
# Orogin line: Ses02M_impro07_M018 [089.2100-090.2200]: What?
#
# Orogin line: Ses02M_impro07_M019 [090.2900-092.4600]: [LAUGHTER] I know. I mean part of-
#
# Orogin line: Ses02M_impro07_F018 [093.4953-101.5200]: [LAUGHTER] like a- like a- [LAUGHTER] No, but I mean like everywhere you go people know who you are.
#
# Orogin line: Ses02M_impro07_M020 [093.5000-097.8100]: Yeah. Right. A cult. I'm looking forward to being in the cult.
#
# Orogin line: Ses02M_impro07_M021 [100.0300-105.2100]: Right I know, like you, it won't hurt, I mean national champions last year, wow, you know
#
# Orogin line: Ses02M_impro07_M022 [105.2200-106.8379]: Maybe we'll do it again this year.
#
# Orogin line: Ses02M_impro07_F019 [105.0100-107.0074]: So you know what you are going to do there?
#
# Orogin line: Ses02M_impro07_M023 [106.8600-114.2900]: What's that? ahh Well, you know I'm I'm thinking um I'm leaning towards like communications
#
# Orogin line: Ses02M_impro07_M024 [114.3000-116.8200]: I-I don't know. Kind of a broad,
#
# Orogin line: Ses02M_impro07_F020 [114.2300-117.6000]: Okay. They have a lot of good schools, right?
#
# Orogin line: Ses02M_impro07_M025 [116.8300-123.9700]: yeah, I mean a lot-a lot  of good stuff oh, yeah, I mean it's- it's just a really good school; so really, whatever I pick I can't go wrong. I mean I'm just
#
# Orogin line: Ses02M_impro07_M026 [123.9800-133.3300]: I'm looking forward to getting there. I mean, God, the campus is cool, you know it's like all just very confined I mean just you know it's a college campus you know it's like
#
# Orogin line: Ses02M_impro07_F021 [132.2869-133.9240]: Yes, it's intimate.
#
# Orogin line: Ses02M_impro07_M027 [133.3400-137.9600]: It's college- oh my God it's college, [GARBAGE] so it's like crazy.
#
# Orogin line: Ses02M_impro07_F022 [136.7900-139.0600]: I know. It's so cool.
#
# Orogin line: Ses02M_impro07_M028 [138.7532-146.4511]: Oh man. So, I don't know you know, we'll see - we'll see how it goes and, yeah, I'm looking forward to it
#
# Orogin line: Ses02M_impro07_F023 [139.2800-143.2800]: Fair for you, Wow, oh my Gosh.
#
# Orogin line: Ses02M_impro07_M029 [146.4611-153.9100]: I mean you got to - you got to show me the ropes 'cause I've never been there before so I mean you know your way around already and- [LAUGHTER]
#
# Orogin line: Ses02M_impro07_F024 [148.7900-150.8500]: I will do the best I can.
#
# Orogin line: Ses02M_impro07_F025 [153.3231-159.1397]: Well, there are all kinds of awesome secrets so you'll really enjoy it. It's really great. I'm so glad.
#
# Orogin line: Ses02M_impro07_M030 [156.4100-158.2700]: Oh, alright.
#
# Orogin line: Ses02M_impro07_M031 [158.2800-166.5386]: I'm-I'm looking forward to that. [BREATHING] man, So yeah, I think I'm going to come out a little early so I mean I'll give you a call and we'll definitely-
#
# Orogin line: Ses02M_impro07_F026 [160.0500-161.5400]: Yay
#
# Orogin line: Ses02M_impro07_F027 [164.0912-166.0000]: Okay. Yes, totally come visit
#
# Orogin line: Ses02M_impro07_F028 [166.0100-170.8121]: and we'll explore and you going to have such a good time, you're going to fit in so well, it's going to be awesome
#
# Orogin line: Ses02M_impro07_M032 [170.6920-174.8175]: [LAUGHTER] Thanks, yes, thanks, yes That'll be cool.
#
# Orogin line: Ses02M_impro07_F029 [171.3800-175.7900]: So Congratulations. That's awesome.
#
# task...
# Orogin line: Ses01M_impro03_M000 [002.9200-005.5600]: The craziest thing just happened to me.
#
# Orogin line: Ses01M_impro03_F000 [005.0200-006.8500]: What?
#
# Orogin line: Ses01M_impro03_M001 [006.3100-011.5700]: This girl; she just offered me fifty thousand dollars to marry her.
#
# Orogin line: Ses01M_impro03_F001 [010.7900-012.0800]: [BREATHING]
#
# Orogin line: Ses01M_impro03_M002 [011.7000-012.9800]: Yeah.
#
# Orogin line: Ses01M_impro03_F002 [012.3700-013.7468]: Why?
#
# Orogin line: Ses01M_impro03_M003 [013.2600-016.8700]: Well, she's not a citizen so she wants to get a visa.
#
# Orogin line: Ses01M_impro03_F003 [016.1900-017.7425]: Is she on the run?
#
# Orogin line: Ses01M_impro03_M004 [017.2800-026.5400]: No, no, no, no, no, no she just... she's not a citizen but she wants her visa, yeah. She's going to pay me fifty thousand dollars to marry her and stay married to her for two years.
#
# Orogin line: Ses01M_impro03_F004 [019.6000-022.1975]: Oh, she just needs to marry you.
#
# Orogin line: Ses01M_impro03_F005 [026.0000-033.2100]: That's incredible. That's awesome. Where's she from?  Maybe you can get a dual citizenship.
#
# Orogin line: Ses01M_impro03_M005 [026.6000-030.7900]: That's like twenty five thousand dollar a year for doing nothing. Isn't that awesome?
#
# Orogin line: Ses01M_impro03_M006 [032.0500-039.5125]: She's actually from England, I think.  Well she- she spoke English but she had an accent. I didn't even ask.
#
# Orogin line: Ses01M_impro03_F006 [035.5000-039.2350]: That's so cool. Uh huh.
#
# Orogin line: Ses01M_impro03_F007 [039.4500-043.7800]: [LAUGHTER] Why did she pick you? Where were you?
#
# Orogin line: Ses01M_impro03_M007 [039.5775-047.6600]: Fifty thousand dollars. Fifty thousand dollars. I was just out... I just... she's - well, she's a friend of friend but like...
#
# Orogin line: Ses01M_impro03_F008 [047.3200-054.5200]: You were at a party? And she's like hey. You seem unattached she's like.
#
# Orogin line: Ses01M_impro03_M008 [048.0800-063.1475]: Yeah.  Can you believe that? Yeah, she's like hey, I'm like sure I'll do it, I don't care. Yeah. I'm like fifty thousand dollars, I'd totally do it for fifty thousand dollars. But the only thing is that's kind of like illegal. So like I could go to jail probably for a long if I get caught, but...
#
# Orogin line: Ses01M_impro03_F009 [055.9325-059.7100]: That's unbelievable... Yeah.
#
# Orogin line: Ses01M_impro03_F010 [061.1325-072.1900]: Well I've known people who have done this before. Yeah.  You just- it's really fun actually 'cause you have like a fake engagement party and all your friends come over and like...
#
# Orogin line: Ses01M_impro03_M009 [063.6350-064.9500]: Have you?
#
# Orogin line: Ses01M_impro03_M010 [070.9500-073.6300]: It's like I'm really going to get married. We'll have like the whole thing.
#
# Orogin line: Ses01M_impro03_M011 [073.6700-075.9600]: Oh, good. [LAUGHTER]
#
# Orogin line: Ses01M_impro03_F011 [072.4875-080.9000]: Yeah. Yeah. And then yeah, and then you know like you could like you could do like like sock her for a lot of money
#
# Orogin line: Ses01M_impro03_M012 [080.7600-082.4800]: I know. What do you think I should-
#
# Orogin line: Ses01M_impro03_F012 [080.9300-088.4500]: Like make her rent the apartment that you two have to live together in, you know. And you won't pay any rent or you pay like, a hundred bucks a month or something.
#
# Orogin line: Ses01M_impro03_M013 [084.5075-086.6600]: Oh good idea.
#
# Orogin line: Ses01M_impro03_M014 [087.4200-090.9600]: Yeah.  Make her like open the bank account and stuff too.
#
# Orogin line: Ses01M_impro03_F013 [090.1100-091.8400]: Yeah.
#
# Orogin line: Ses01M_impro03_M015 [091.3700-093.4700]: It's a good idea.
#
# Orogin line: Ses01M_impro03_F014 [092.8700-096.1300]: Dude, you lucked out.
#
# Orogin line: Ses01M_impro03_M016 [094.7700-098.7000]: I know.  Also I get to like plan the wedding now too. That will be fun.
#
# Orogin line: Ses01M_impro03_F015 [097.3500-103.9875]: Yeah.  My colors are blush and beige what is it, do you know?
#
# Orogin line: Ses01M_impro03_M017 [103.1000-114.4300]: Something blue, something new, something... no I don't know. [LAUGHTER] So yeah, wonder if she's going to pay me up front but do you think it's bad though, do you think they're going to like track the money or something?
#
# Orogin line: Ses01M_impro03_F016 [104.6375-109.0600]: Oh I don't know. [LAUGHTER]
#
# Orogin line: Ses01M_impro03_F017 [113.7900-116.7000]: I don't know get it in cash.
#
# Orogin line: Ses01M_impro03_M018 [115.8400-117.8900]: Just cash hardcore.
# Orogin line: Ses01M_impro03_F018 [117.2100-118.4700]: Yeah.
#
# Orogin line: Ses01M_impro03_M019 [117.9800-121.7600]: What should we do?  Where should we get married? We should have party.
#
# Orogin line: Ses01M_impro03_F019 [120.0300-123.6400]: How exciting. You should have a wedding on the beach.
#
# Orogin line: Ses01M_impro03_M020 [121.8300-125.1400]: Yeah, like a big like- A wedding on the beach, that would be nice.
#
# Orogin line: Ses01M_impro03_F020 [123.9600-125.7400]: Yeah, at night.
#
# Orogin line: Ses01M_impro03_M021 [125.3200-134.0075]: And then we can honeymoon.  I want to go tropical though like Bahamas- --or like Tahiti or something. I just want to like beach and like drink.
#
# Orogin line: Ses01M_impro03_F021 [128.0600-131.5900]: Oh yeah, absolutely, absolutely.
#
# Orogin line: Ses01M_impro03_F022 [132.1600-136.1500]: How exciting.  You should make her bring all your friends too.
#
# Orogin line: Ses01M_impro03_M022 [135.6600-145.4400]: I'll make her pay for that.  I hear she's like totally wealthy. She's like royalty- --or something like and- --whatever like removed or something but yeah.
#
# Orogin line: Ses01M_impro03_F023 [136.2900-144.0700]: [GARBAGE] She's got to be loaded.  fifty thousand dollars.  That's incredible.
#
# Orogin line: Ses01M_impro03_F024 [144.6100-146.4100]: Incredible.
#
# Orogin line: Ses01M_impro03_M023 [145.9700-150.5100]: I'm going to marry a blue blood. [LAUGHTER]
#
# Orogin line: Ses01M_impro03_F025 [147.1700-150.8450]: you're a lucky, lucky, lucky man.
#
# Orogin line: Ses01M_impro03_M024 [150.5800-152.0400]: Will you help me plan?
#
# Orogin line: Ses01M_impro03_F026 [151.2600-153.9075]: Oh, totally. Yeah.
#
# Orogin line: Ses01M_impro03_M025 [152.1000-153.2500]: Good.
#
# task...
# Orogin line: Ses02F_impro07_M000 [006.7677-009.5033]: So, how's it going?
#
# Orogin line: Ses02F_impro07_F000 [009.1738-013.9432]: It's going really well.  Um, I received something in the mail today.
#
# Orogin line: Ses02F_impro07_M001 [013.9746-016.8885]: Oh, you got what?  Where?
#
# Orogin line: Ses02F_impro07_F001 [017.2750-019.5500]: I got into U.S.C.
#
# Orogin line: Ses02F_impro07_M002 [019.0400-020.8700]: Oh, no way.
#
# Orogin line: Ses02F_impro07_F002 [020.4600-022.9300]: Yeah, I'm so excited.  So I'm gonna say--
#
# Orogin line: Ses02F_impro07_M003 [021.8500-023.5100]: Are you gonna go? you gonna-
#
# Orogin line: Ses02F_impro07_F003 [022.9400-028.7400]: Yeah, I think, I mean because where else would I gonna go?  Like the other places that I applied to I really didn't like that much anyway.
#
# Orogin line: Ses02F_impro07_F004 [028.7500-029.9500]: So--
#
# Orogin line: Ses02F_impro07_M004 [028.1700-029.5900]: Wow, that's...
#
# Orogin line: Ses02F_impro07_M005 [029.6100-035.0773]: ...that's first choice, huh? That's so awesome and now look you're gonna be--you're gonna be here. you know
#
# Orogin line: Ses02F_impro07_F005 [029.9700-031.0789]: Yeah, I know.
#
# Orogin line: Ses02F_impro07_F006 [031.0983-033.0000]: Absolutely. I'm so excited.
#
# Orogin line: Ses02F_impro07_F007 [034.4500-040.6077]: I know.  I know. And we'll all get to hang out.  And I'm--even though we'll be at like at different parts of the city, we can still, like...
#
# Orogin line: Ses02F_impro07_F008 [040.6300-048.3500]: ...hang out and, like, have our different lives--And meet each other's friends and stuff.  So, I'm just so glad 'cause they have such a good school
#
# Orogin line: Ses02F_impro07_M006 [040.6900-043.5800]: Yeah, no, definitely--It's gonna..
#
# Orogin line: Ses02F_impro07_M007 [044.6000-045.8200]: Yeah.
#
# Orogin line: Ses02F_impro07_F009 [048.3700-052.6300]: and like-- The football team--And like all the-...you- what I mean, like...
#
# Orogin line: M: Wow.
#
# Error caused by:  ['M:', 'Wow.\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session2/dialog/transcriptions/Ses02F_impro07.txt
# Orogin line: Ses02F_impro07_M008 [050.0900-051.4100]: Yeah
#
# Orogin line: Ses02F_impro07_M009 [051.4700-052.6100]: Fight on.
#
# Orogin line: Ses02F_impro07_F010 [052.6300-057.8000]: You can walk somewhere and be anywhere in the country and be like, oh, yeah, I am at U.S.C.
#
# Orogin line: Ses02F_impro07_F011 [057.8100-065.9300]: And you know what, you know what I mean, like it's recognizable rather than just being like I went some random school. It's like people really know what you...
#
# Orogin line: Ses02F_impro07_M010 [057.4500-060.5700]: [LAUGHTER]
#
# Orogin line: Ses02F_impro07_M011 [063.1430-064.9973]: Wow. That's cool.
#
# Orogin line: Ses02F_impro07_F012 [065.9400-071.1900]: ...like, they feel like--I feel like it's going to be so like accomplished.  Do you know what I mean?
#
# Orogin line: Ses02F_impro07_F013 [071.2000-074.5000]: Like it has some prestige. so
#
# Orogin line: Ses02F_impro07_M012 [071.3699-074.5199]: Yeah. Hey. Prestigious school.
#
# Orogin line: Ses02F_impro07_M013 [074.5199-078.2500]: So, what, do you have to send in your deposit now?  Or what you-?
#
# Orogin line: Ses02F_impro07_F014 [077.3100-083.5700]: Yeah, I mean there's all the money stuff and my mom's helping me with the financial aid and stuff.  But, it'll be fine--
#
# Orogin line: Ses02F_impro07_F015 [083.5800-087.5300]: Like, now that I'm accepted, it's just, like, such a huge load off my mind.
#
# Orogin line: Ses02F_impro07_M014 [082.8800-084.2100]: That's great.
#
# Orogin line: Ses02F_impro07_F016 [087.5400-089.9800]: I don't mind worrying about all the paperwork.  You know--
#
# Orogin line: Ses02F_impro07_M015 [088.3886-089.5200]: Yeah.
#
# Orogin line: Ses02F_impro07_M016 [090.0200-091.1200]: So...
#
# Orogin line: Ses02F_impro07_F017 [090.0000-096.9445]: Because, I don't have to like make that decision anymore.  I don't have to try and decide, like, what the bad school I'm going to go to is. you know
#
# Orogin line: Ses02F_impro07_M017 [095.5900-101.1500]: Right.  Right.  Right. Oh, man, then you're going to have to do orientation, I guess.
#
# Orogin line: Ses02F_impro07_F018 [100.0166-111.3549]: I know. I know.  I think you go and you like stay for a couple of days and you meet people and--And they'll give you like a tour--And show you everything.  Oh, man, I'm just so--I'm so excited.
#
# Orogin line: M: Oh boy. Right. Yeah. It'll be crazy.
#
# Orogin line: Ses02F_impro07_M018 [108.7087-110.3028]: That'll be awesome.
#
# Orogin line: Ses02F_impro07_M019 [110.3312-112.5500]: I mean because you went to the campus before, right?
#
# Orogin line: Ses02F_impro07_F019 [111.9500-121.2900]: Yeah, oh totally.  It's a beautiful campus.  It's gonna be really nice.  Um, and everyone is friendly and like there's ivy on all the walls.  Oh, it's just so--it's so like collegiate.
#
# Orogin line: Ses02F_impro07_F020 [121.3000-123.8909]: You know what I mean?  Like, it's like exactly what I want.
#
# Orogin line: Ses02F_impro07_M020 [123.1375-127.2904]: So what're you--what're you gonna do there?  Have you decided?  Thought about it?
#
# Orogin line: Ses02F_impro07_F021 [125.8858-133.4000]: Well, you know, I've thought about it but they have so many things that I might--Like try some things out first...
#
# Orogin line: Ses02F_impro07_M021 [130.0139-132.6988]: I know.  I mean, it's good all around.
#
# Orogin line: Ses02F_impro07_F022 [133.4200-144.7518]: ...because also on the list of their, um, like G.E.'s or whatever, you have a lot of choices within every single one.  So you can, like, try things out and not just be like, oh, I have to take math, oh, I have to take this.  You know what I mean?
#
# Orogin line: Ses02F_impro07_F023 [144.7600-146.4500]: So, um, so I don't know.
#
# Orogin line: Ses02F_impro07_M022 [143.7874-145.6256]: [LAUGHTER]
#
# Orogin line: Ses02F_impro07_F024 [146.4700-148.6500]: I mean I'm gonna take a bunch of stuff and see.
#
# Orogin line: Ses02F_impro07_M023 [148.7694-150.1409]: Oh man.
#
# Orogin line: Ses02F_impro07_F025 [148.6700-156.3102]: I- They have like--they just have so many like prestigious like this school is top ten and like the departments within it, you know what I mean.
#
# Orogin line: Ses02F_impro07_M024 [156.3531-159.9725]: I always see people walking around with like U.S.C stuff on--
#
# Orogin line: Ses02F_impro07_F026 [159.7568-165.8800]: I know, I get to be one of those now--I'll like walk around and be like a U.S.C..  You know what I mean.
#
# Orogin line: Ses02F_impro07_M025 [159.9725-160.8800]: You know is like.
# Orogin line: Ses02F_impro07_M026 [160.8997-162.2100]: I know.
#
# Orogin line: Ses02F_impro07_M027 [163.2400-164.9300]: Ahh. Yeah. [GARBAGE]
#
# Orogin line: Ses02F_impro07_M028 [165.5326-173.6674]: You'll be like are you a fan or a student you know? Student. [LAUGHTER] Oh man, that's awesome.
#
# Orogin line: Ses02F_impro07_F027 [166.9600-168.2600]: And you'll be like...
#
# Orogin line: Ses02F_impro07_F028 [168.2900-172.3000]: Student. I'm a student. Yes I am, Thank you very much.
#
# Orogin line: Ses02F_impro07_F029 [172.5300-173.6000]: [BREATHING]
#
# Orogin line: Ses02F_impro07_M029 [173.7000-178.7860]: A U.S.C. graduate now. You're set.
#
# Orogin line: Ses02F_impro07_F030 [173.8219-175.6762]: I know.  I'm excited.
#
# Orogin line: Ses02F_impro07_F031 [177.1500-179.8400]: Well, that'll take a while. [GARBAGE]
#
# Orogin line: Ses02F_impro07_M030 [179.5400-183.4990]: I know, that's a ways down the road. That's cool.
#
# Orogin line: Ses02F_impro07_F032 [180.3892-182.3015]: That's going to be a lot of work.
#
# Orogin line: Ses02F_impro07_F033 [182.3100-186.7475]: But, it'll be fine, I mean.  I'm so excited. It's going to be so fun.
#
# Orogin line: Ses02F_impro07_M031 [185.0531-187.1315]: In LA. Oh man.
#
# Orogin line: Ses02F_impro07_F034 [187.1942-193.4503]: I know, and I mean the area's not great, but like the school makes up for it. It'll be fine. It'll be good.
#
# Orogin line: Ses02F_impro07_M032 [188.3100-189.6200]: So much.
#
# Orogin line: Ses02F_impro07_M033 [190.0100-192.4500]: But it's LA, you know, everything.
#
# Orogin line: Ses02F_impro07_M034 [192.5002-195.3199]: You're getting close to the beach.  I mean geez.
#
# Orogin line: Ses02F_impro07_F035 [195.3825-199.0482]: I know. I know. So fun.  I can't wait.
#
# Orogin line: Ses02F_impro07_M035 [198.3914-203.6839]: Cool.  Well give me a call, you know when--You get in town. definitely Awesome.
#
# Orogin line: Ses02F_impro07_F036 [200.2705-202.5100]: I will. I will. Thank you.
#
# Orogin line: Ses02F_impro07_F037 [202.5700-204.2100]: Thanks.
#
# task...
# Orogin line: Ses01F_impro07_M000 [002.9700-004.7800]: Did you get the letter?
#
# Orogin line: Ses01F_impro07_F000 [003.9500-010.5900]: Yes.  There's a big envelope it says, you're in. I know.
#
# Orogin line: Ses01F_impro07_M001 [007.5325-011.9600]: Yeah. That is so awesome.
#
# Orogin line: M: Did you-
#
# Orogin line: Ses01F_impro07_M002 [013.9200-019.0900]: Oh my God. What are you going to do? [LAUGHTER]
#
# Orogin line: Ses01F_impro07_F001 [011.3600-016.5575]: So I have to move back to the ghetto but...I know.
#
# Orogin line: Ses01F_impro07_M003 [020.6800-028.0600]: Oh-Yeah, I bet you're really excited. Oh.  That's what loans are for?  Right? Exactly.
#
# Orogin line: Ses01F_impro07_F002 [019.6100-031.6500]: I'm really excited.  Yeah. I don't know how I'm going to pay for anything, but... I also- Yeah.  Loans, too, yeah. I applied, though, for a bunch of grants and scholarships so I'm still waiting to hear on that.
#
# Orogin line: Ses01F_impro07_M004 [030.9150-038.8100]: Oh.  Good, good.  That's awesome. Are you going to stay around here?  Or are you going to like get a different neighborhood- you going to move to a different neighborhood?
#
# Orogin line: Ses01F_impro07_F003 [032.5200-034.9000]: Oh- I know, I know, I know, I know.
#
# Orogin line: Ses01F_impro07_F004 [037.1625-042.4900]: I don't know.  I spend so much time commuting as it is, I'd rather.
#
# Orogin line: Ses01F_impro07_M005 [041.1700-046.9975]: This is so- I am so happy that you're going to stay.  You're not going to...We should totally throw a party.
#
# Orogin line: Ses01F_impro07_F005 [042.9550-045.8850]: I know. We should throw a party.
#
# Orogin line: Ses01F_impro07_F006 [046.2800-055.4100]: At Arapaho we could afford that. [GARBAGE]. Yeah.  So what are you doing this summer, though?  You're staying around, too, yeah?
#
# Orogin line: Ses01F_impro07_M006 [047.1100-052.8125]: A rapper party ho. Yeah. Okay.
#
# Orogin line: Ses01F_impro07_M007 [054.1600-063.2800]: I am just- Yeah.  I'm sticking around, I'm just doing my thing.  I'm living here.  I'm so glad you're going to stay, I'm so glad you're going to be here. Yeah. Woo.
#
# Orogin line: F:Yay.
#
# Orogin line: Ses01F_impro07_F007 [063.0200-072.7500]: It's a relief too. I mean I was thinking I was going to have to pack up all of my stuff but yeah. Hooray for U.S.C.
#
# Orogin line: Ses01F_impro07_M008 [064.6275-067.2400]: Yeah.  Big time.
#
# Orogin line: Ses01F_impro07_M009 [067.7250-074.0325]: Mmhmm. Mmhmm. Yay. So what major?  What are you doing?
#
# Orogin line: Ses01F_impro07_F008 [073.5050-080.7800]: Umm. It's...It's uhh...It's Critical Studies. It's a really prestigious program, so they say.
#
# Orogin line: Ses01F_impro07_M010 [076.6200-078.1700]: Oh, okay.
#
# Orogin line: Ses01F_impro07_M011 [078.8400-081.3600]: Ooh. Fancy.
#
# Orogin line: Ses01F_impro07_F009 [081.0275-083.3050]: Yeah.  I'm not sure.
#
# Orogin line: Ses01F_impro07_M012 [082.6575-087.1025]: Is this a Masters or a P.h.D.?  Or can you...? Nice
#
# Orogin line: Ses01F_impro07_F010 [084.5100-088.3100]: Umm...P.h.D. [LAUGHTER]
#
# Orogin line: Ses01F_impro07_M013 [087.5875-090.6500]: That's good.  Don't you have to like teach a class, too, when you do that?
#
# Orogin line: Ses01F_impro07_F011 [089.5600-094.8150]: Um, yeah, yeah.  I'm a TA for two sessions. Mmhmm.
#
# Orogin line: Ses01F_impro07_M014 [094.2900-099.3700]: Teacher. Mrs. Nash, I have a question.
#
# Orogin line: Ses01F_impro07_F012 [094.8600-100.7400]: So I get to mold young minds. Mrs.?  That's my mother.
#
# Orogin line: Ses01F_impro07_M015 [099.9875-110.5400]: You have to get married.  Well you are married to Chuck.  You're Mrs. Nash.  Not to be confused with Mrs. Dash which is the popular seasoning.
#
# Orogin line: F:[GARBAGE]
#
# Error caused by:  ['F:[GARBAGE]', '\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro07.txt
# Orogin line: Ses01F_impro07_F013 [103.2600-110.4600]: I would be like- Oh. Right, right, right.
#
# Orogin line: Ses01F_impro07_M016 [110.5400-116.2800]: Mrs. Nash.  That's so awesome, though.
#
# Orogin line: Ses01F_impro07_F014 [115.6800-126.4100]: Yeah. Yeah I'm excited. Hooray.  And then I'll be a millionaire once I graduate, you understand? Because that's the way it works.
#
# Orogin line: Ses01F_impro07_M017 [116.2800-119.8507]: Yay...School's fun.
#
# Orogin line: Ses01F_impro07_M018 [123.2575-128.0400]: Of course, right.  That's where the real money is, being a student.
#
# Orogin line: Ses01F_impro07_F015 [127.4300-130.3175]: Yeah.  Totally. [LAUGHTER]
#
# Orogin line: Ses01F_impro07_M019 [128.5400-141.6850]: That's how you get the big bucks.  Are you messing with the chair? Don't ruin it.
#
# Orogin line: Ses01F_impro07_F016 [133.3125-142.3625]: I know. I made such a mess of it, the entire time.  The last three things I've done, I've ruined everything, I think. Mm-hmm.  Yeah.
#
# task...
# Orogin line: Ses01F_script01_1_F000 [006.2100-009.3200]: What's he going to say?
#
# Orogin line: Ses01F_script01_1_F001 [009.3500-012.8955]: Maybe we should tell him before he sees it.
#
# Orogin line: Ses01F_script01_1_M000 [011.9892-015.1219]: He saw it.
#
# Orogin line: Ses01F_script01_1_F002 [014.3063-019.5526]: How could he see it?  I was the first one up; he was still in bed.
#
# Orogin line: Ses01F_script01_1_M001 [019.0456-022.3962]: He was out here when it broke.
#
# Orogin line: Ses01F_script01_1_F003 [022.3200-024.6667]: When?
#
# Orogin line: Ses01F_script01_1_M002 [024.8000-035.9971]: Four o clock this morning.  I heard a crack and I woke up and looked out.  He was standing right over there when it cracked.
#
# Orogin line: Ses01F_script01_1_F004 [035.3799-039.0900]: What was he doing out here at four o clock in the morning?
#
# Orogin line: Ses01F_script01_1_M003 [038.6600-040.5300]: I don't know.
#
# Orogin line: Ses01F_script01_1_F005 [040.0200-044.9688]: He's dreaming of him again, walking around.
#
# Orogin line: Ses01F_script01_1_M004 [044.5500-047.2300]: I guess he is.
#
# Orogin line: Ses01F_script01_1_F006 [046.9500-052.3200]: It's getting to be just like after he died.  What's the meaning of that?
#
# Orogin line: Ses01F_script01_1_M005 [051.4300-059.5500]: I don't know the meaning of it.  But I know one thing, Mom, you've made a terrible mistake with father.
#
# Orogin line: Ses01F_script01_1_F007 [058.9500-060.8800]: What?
# Orogin line: Ses01F_script01_1_M006 [062.1628-068.2500]: Being dishonest with him, you know.  This kind of thing always pays off and it's paying off.
#
# Orogin line: Ses01F_script01_1_F008 [067.6000-070.6700]: What do you mean dishonest?
#
# Orogin line: Ses01F_script01_1_M007 [070.0764-078.8718]: You know Larry is not coming back and I know it.  Why do we allow him to go on thinking that we believe with him?
#
# Orogin line: Ses01F_script01_1_F009 [078.3648-081.5611]: What do you want to do?  Argue with him?
#
# Orogin line: Ses01F_script01_1_M008 [081.4068-089.4307]: I don't want to argue but it's time he realized that nobody believes Larry is alive.
#
# Orogin line: Ses01F_script01_1_M009 [089.7172-101.3800]: You know?  Why shouldn't he walk the nights thinking of him, dreaming of him?   Do we contradict him?  Do we say, we don't have any hope anymore?  That we haven't had any hope for years now?
#
# Orogin line: Ses01F_script01_1_F010 [100.1400-102.3482]: You can't say that to him.
#
# Orogin line: Ses01F_script01_1_M010 [102.1000-104.7200]: We've got to say it to him.
#
# Orogin line: Ses01F_script01_1_F011 [104.2900-108.7408]: Where's the proof?  Do you have any proof?
#
# Orogin line: Ses01F_script01_1_M011 [108.1897-118.4700]: For God's sake, three years?  Nobody comes back after three years; that's insane.
#
# Orogin line: Ses01F_script01_1_F012 [117.8228-129.5100]: To you it is, to me it is, but to your father, you can talk yourself until you are blue in the face.  But there is no grave and there is no body, so where are you?
#
# Orogin line: Ses01F_script01_1_M012 [130.7600-134.5900]: Sit down, Mom.  I want to talk to you.
#
# Orogin line: Ses01F_script01_1_F013 [134.0100-141.9500]: It's that the trouble is those God damn newspapers.  Every month some new boy comes back and so the next one is going to be Larry, they just--
#
# Orogin line: Ses01F_script01_1_M013 [141.0500-149.7500]: All right, all right, all right.  You know why I asked Annie here, right?
#
# Orogin line: Ses01F_script01_1_F014 [150.2700-152.6736]: Why?
#
# Orogin line: Ses01F_script01_1_M014 [153.8860-155.8699]: You know.
#
# Orogin line: Ses01F_script01_1_F015 [156.1786-160.6700]: Well I got an idea, but what's your story?
#
# Orogin line: Ses01F_script01_1_M015 [161.9980-165.3487]: I'm going to ask her to marry me.
#
# Orogin line: Ses01F_script01_1_F016 [165.6573-169.5590]: Well that's only your business, Chris.
#
# Orogin line: Ses01F_script01_1_M016 [169.7574-172.1800]: You know it's not just my business.
#
# Orogin line: Ses01F_script01_1_F017 [171.6300-175.4900]: Well what do you want me to do?  You're old enough to know your own mind.
#
# Orogin line: Ses01F_script01_1_M017 [174.7833-177.7200]: So all right then, I'll just go ahead with it?
#
# Orogin line: Ses01F_script01_1_F018 [176.9600-179.7500]: Well you want to make sure that your father is not going to --
#
# Orogin line: Ses01F_script01_1_M018 [179.2800-181.9475]: Then it's not just my business.
#
# Orogin line: Ses01F_script01_1_F019 [183.9800-186.0500]: I'm just saying.
#
# Orogin line: Ses01F_script01_1_M019 [185.0300-195.2800]: You know sometimes you infuriate me.  you know that?  Isn't it your business if I tell father and he throws a fit about it?  God, you have such a talent for ignoring things.
#
# Orogin line: Ses01F_script01_1_F020 [194.0600-198.9100]: Oh.  I ignore what I got to ignore.  That girl is Larry's girl.
#
# Orogin line: Ses01F_script01_1_M020 [197.6000-199.7475]: She's not Larry's girl.
#
# Orogin line: F: Line.
#
# Error caused by:  ['F:', 'Line.\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script01_1.txt
# Orogin line: M: From mother's point of view, he's not dead.
#
# Orogin line: Ses01F_script01_1_F021 [205.1600-215.1700]: From your father's point of view, he is not dead and- Chris he still thinks he's still alive.  The girl is Larry's girl.
#
# Orogin line: F: From...line.
#
# Error caused by:  ['F:', 'From...line.\n']
# In file: auditary_emotion_recognition/IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script01_1.txt
# Orogin line: M: Now you can go on from here.
#
# Orogin line: Ses01F_script01_1_F022 [219.0400-223.8200]: Now you can go on from there if you know where to go, but I'm telling you, I don't know where to go.
#
# Orogin line: Ses01F_script01_1_M021 [224.7000-236.0500]: I don't know why it is, but every time I reach out for something I have to pull back because I am afraid other people will suffer. My whole bloody life, time after time.
#
# Orogin line: F: You're --
#
# Orogin line: Ses01F_script01_1_F023 [235.2000-238.5600]: You're a considerate fellow, there's nothing wrong in that.
#
# Orogin line: Ses01F_script01_1_M022 [237.8000-240.4290]: To hell with that.
#
# Orogin line: Ses01F_script01_1_F024 [241.3769-245.1904]: I just don't see why.  Have you asked Annie yet?
#
# Orogin line: Ses01F_script01_1_M023 [245.2786-247.5700]: I wanted to get this settled first.
#
# Orogin line: Ses01F_script01_1_F025 [246.8000-251.4508]: Well how do you know she's going to marry you?  Maybe she feels the same way your father does.
#
# Orogin line: Ses01F_script01_1_M024 [251.2965-261.0500]: Well if she does, then that's it.  That's the end of it.  From her letters, though, I think she's pretty much forgotten him.
#
# Orogin line: Ses01F_script01_1_M025 [262.6500-267.2119]: And then we'll thrash it out with father.  Okay Mom?  Don't avoid me.
#
# Orogin line: Ses01F_script01_1_F026 [266.8300-270.7300]: The trouble is you don't see enough women.  You never did.
#
# Orogin line: Ses01F_script01_1_M026 [269.7300-274.6626]: So what.  I'm not fast with women.
#
# Orogin line: Ses01F_script01_1_F027 [274.1997-277.2100]: Why does it have to be Annie?
#
# Orogin line: Ses01F_script01_1_M027 [276.2400-278.3659]: Because it is.
#
# ...
#
# Orogin line: Ses03M_impro08a_M001 [017.6481-020.8228]: I'm sorry ma'am, what can I help you with?
#
# Orogin line: Ses03M_impro08a_F001 [019.8763-026.9925]: Look my, my phone isn't working.  I don't understand what's going on.  I am trying to call out.  I'm not receiving any calls
#
# Orogin line: Ses03M_impro08a_F002 [027.0735-031.6225]: and I need assistance with my...not only is my work phone, it's my home phone and look,
#
# Orogin line: Ses03M_impro08a_F003 [031.7275-036.8342]: this is my business.  This is how I make money is through my phone.  It needs to be working.  Can you please help me?
#
# Orogin line: Ses03M_impro08a_M002 [034.1722-042.0202]: Okay.  Can you give me the last four digits of your social security number so I can verify who I'm speaking with?
#
# Orogin line: Ses03M_impro08a_F004 [041.3695-044.4061]: two two six six.
#
# Orogin line: Ses03M_impro08a_M003 [043.4794-046.8315]: Okay.  And your name is?
#
# Orogin line: Ses03M_impro08a_F005 [045.9836-048.5076]: Olivia.
#
# Orogin line: Ses03M_impro08a_M004 [047.7977-053.2597]: Olivia. Um. Okay.  So how long has this problem been?
#
# Orogin line: Ses03M_impro08a_F006 [052.5302-061.8176]: This has been going on for the past two weeks.  I called every single day.  Nobody is helping me.  You guys tell me the same thing over and over, call again, call again, call again--
#
# Orogin line: Ses03M_impro08a_M005 [060.1218-062.9021]: So what exactly is the problem?
#
# Orogin line: Ses03M_impro08a_F007 [061.8767-069.4487]: I don't, I don't know what the problem is.  That's what I want you guys to...why is my service not turned on?  And I paid my bills on time.  I don't understand.
#
# Orogin line: Ses03M_impro08a_M006 [068.6402-077.5530]: Um- I think part of it has to do with the network being down.  It's been having some trouble the last few weeks--
#
# Orogin line: Ses03M_impro08a_F008 [074.8318-081.1900]: Okay.  Well that is, that is fine and all.  I don't care.  I really don't care because I want my phone to work that's all.
#
# Orogin line: Ses03M_impro08a_F009 [081.2225-092.2433]: That is I am paying you guys for service and I'm not getting any service.  I get, I get just dropped calls all the time and now it's completely not working at all.  I can't even call out, nine one one probably wouldn't even work.
#
# Orogin line: Ses03M_impro08a_M007 [087.7474-090.4292]: I understand--we're not-
#
# Orogin line: Ses03M_impro08a_M008 [091.0602-095.6349]: No.  Okay.  We're not charging you for any of these months.  We're going to give you three months free.
#
# Orogin line: Ses03M_impro08a_F010 [094.6884-099.7560]: Well you better.  You better give me a whole freaking new phone that's what you better do.
#
# Orogin line: Ses03M_impro08a_M009 [098.8687-101.6293]: We can give you a new phone--
#
# Orogin line: Ses03M_impro08a_F011 [099.9335-102.3589]: I want a camera phone actually.
#
# Orogin line: Ses03M_impro08a_M010 [101.7279-107.3871]: We can do that.  We can do that.  You just have to sign a one-year contract though with the--
#
# Orogin line: Ses03M_impro08a_F012 [105.5533-110.1575]: No, no, no...  I'm done with these contract business because this is what can happen.
#
# Orogin line: Ses03M_impro08a_F013 [110.2000-117.8182]: You sign the contract and then down the line the phone doesn't work and you're stuck, you can't go to a new...no.  No contracts for me.  You give me a new phone.
#
# Orogin line: Ses03M_impro08a_M011 [116.2210-122.3732]: Besides, it's sort of out of hands at the moment----The whole electrical power outage.
#
# Orogin line: Ses03M_impro08a_F014 [118.4295-121.2295]: I want to talk to a supervisor
#
# Orogin line: Ses03M_impro08a_F015 [121.3084-126.2775]: I would like to talk to your supervisor.  Obviously you're incompetent and don't understand what I'm asking.
#
# Orogin line: Ses03M_impro08a_M012 [125.5676-133.9480]: Um- Let me connect you to my supervisor.  Actually, he's out right now so I'm supervisor until he comes back. Um-
#
# Orogin line: Ses03M_impro08a_F016 [132.0353-134.4212]: What?
#
# Orogin line: Ses03M_impro08a_M013 [134.2043-140.4156]: So you could----speak with me some more, you could call back later on maybe.
#
# Orogin line: Ses03M_impro08a_F017 [134.4804-137.0635]: That's ridiculous.  You know?
#
# Orogin line: Ses03M_impro08a_F018 [138.8579-146.9819]: No I don't want to call back, you put me on hold for like hours and hours----and it's money, money, money, money and out of my pocket, out of my pocket--
#
# Orogin line: Ses03M_impro08a_M014 [141.8945-144.4579]: I didn't put you on hold.
#
# Orogin line: Ses03M_impro08a_M015 [144.5565-150.0974]: There are a lot of people calling us having problems.  Every phone company is having the same problems ma'am
#
# Orogin line: Ses03M_impro08a_F019 [149.4664-152.4439]: Every phone...every single phone company?
#
# Orogin line: Ses03M_impro08a_M016 [151.3989-157.4327]: Mmm hmmm.  Mmm hmmm.  The power outages, everything, hurricane Katrina. Everything's really messed up.
#
# Orogin line: Ses03M_impro08a_F020 [154.2778-158.6553]: This is ridiculous.Well what are we supposed to do?  We starve then because I can't use my phone cause
#
# Orogin line: Ses03M_impro08a_F021 [158.6750-166.4244]: I am a realtor and this is my business.  People are calling me all the time but you know, and I don't have a land line.  I can't afford to have a land line
#
# Orogin line: Ses03M_impro08a_M017 [162.1454-164.3145]: don't you-
#
# Orogin line: Ses03M_impro08a_M018 [165.8131-170.0329]: I'm really sorry ma'am.  There's not----a lot we can do for it.
#
# Orogin line: Ses03M_impro08a_F022 [167.5680-169.7174]: That you better be sorry.
#
# Orogin line: Ses03M_impro08a_F023 [169.7568-173.6019]: Well you're not helping me at all.  God this is so frustrating.
#
# Orogin line: Ses03M_impro08a_M019 [171.3737-181.1935]: What I can do for you, if you want to make a call right now I could contact you through our computer.  I can call through my phone and you can speak through me.
#
# Orogin line: Ses03M_impro08a_F024 [180.0104-183.8753]: What?  No.  That's way too complicated.  Look--
#
# Orogin line: Ses03M_impro08a_F025 [183.8875-188.0359]: you need to fix my phone.  I don't care what you have to do--
#
# Orogin line: Ses03M_impro08a_M020 [185.9851-190.8753]: I'm sorry it has to do with an electrical power outage and stuff--
#
# Orogin line: Ses03M_impro08a_F026 [188.5288-196.8895]: Well then go up the freaking pole and fix it like, you need to help me.  You don't understand I'm in dire, dire need of a phone right now.
#
# Orogin line: Ses03M_impro08a_M021 [196.2388-203.5544]: Well, okay I'm going to give you a free phone card that you can use at any payphone and that's on us. Okay?
#
# Orogin line: Ses03M_impro08a_F027 [201.0304-207.7347]: Yeah yeah, woman going out in South Central on the payphone at night.  Oh that's real safe.
#
# Orogin line: Ses03M_impro08a_M022 [206.9065-211.1854]: I'm, I'm sorry you chose to live there um--
#
# Orogin line: Ses03M_impro08a_F028 [209.8840-215.3575]: No, no, no.  I didn't choose to live here.  I work there.  Okay?  Yeah. work work work
#
# Orogin line: Ses03M_impro08a_MXX0 [213.9491-214.7541]: okay.
#
# Orogin line: Ses03M_impro08a_M023 [214.8728-218.8559]: Well I'm sure maybe there's a phone at work you could use.
#
# Orogin line: Ses03M_impro08a_F029 [218.1658-225.7180]: We can't call out.  We can't make out-- line.  I don't work, I work at another office.
#
# Orogin line: Ses03M_impro08a_F030 [225.7771-229.8392]: A law firm.  Thank you very much.
#
# Orogin line: Ses03M_impro08a_M024 [227.9067-231.1406]: All right um--
#
# Orogin line: Ses03M_impro08a_F031 [230.4899-239.5801]: I work out of my home as a realtor and because I don't have a land line, I need a phone and because of now I don't have one I don't know what to do.  And you're not helping me at all.
#
# Orogin line: Ses03M_impro08a_F032 [239.6393-242.9323]: In fact, give me your name sir, what's your name again?
#
# Orogin line: Ses03M_impro08a_M025 [242.3999-246.0675]: My name is Sara.
#
# Orogin line: Ses03M_impro08a_F033 [245.3971-248.9070]: Okay.  Sara what?
# Orogin line: Ses03M_impro08a_M026 [247.9999-250.6619]: Sara Brown.
#
# Orogin line: Ses03M_impro08a_F034 [249.7746-262.7494]: Sara Brown.  Sara Brown, um- yeah, I'm going to get off the phone with you. And then I'm going to call back and I'm going to give your supervisor your name because you're obviously incompetent to work here.
#
# Orogin line: Ses03M_impro08a_MXX1 [255.3251-256.3542]: Okay.
#
# Orogin line: Ses03M_impro08a_M027 [261.2113-268.4283]: You know maam, we record this conversation so anything you say can be proven in a law of court so keep that in mind.
#
# Orogin line: Ses03M_impro08a_F035 [266.4367-274.7974]: What are you, what are you a police officer now?  You know, like I'm done, I'm over it.  Goodbye and I hope that you lose your job.
#
# task...
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session3/sentences/wav/Ses03F_impro08/Ses03F_impro08_M018.wav
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F033.wav
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session3/sentences/wav/Ses03M_impro06/Ses03M_impro06_M003.wav
# Orogin line: Ses03M_impro03_M000 [000.4621-003.0025]: Hey.
#
# Orogin line: Ses03M_impro03_F000 [002.3299-004.6150]: Hey.
#
# Orogin line: Ses03M_impro03_M001 [004.0436-007.3747]: Esmeralda, guess what?
#
# Orogin line: Ses03M_impro03_F001 [006.2964-007.8946]: What?
#
# Orogin line: Ses03M_impro03_M002 [007.5288-014.0755]: [LAUGHTER] Guess who just got hitched?
#
# Orogin line: Ses03M_impro03_F002 [014.2850-025.0825]: Shut up. Oh my God.  Really? Just like that?  You just asked the question and what...how did you ask?
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session2/sentences/wav/Ses02F_script02_1/Ses02F_script02_1_M030.wav
#
# Orogin line: Ses03M_impro03_M003 [014.1525-021.7776]: This guy. Yeah.  Can you believe it? She said yes too. Yeah.  She said yes.
#
# Orogin line: Ses03M_impro03_M004 [023.4975-027.2268]: Okay we were at Chuck E. Cheese.
#
# Orogin line: Ses03M_impro03_F003 [025.1665-028.9250]: Chuck E. Cheese?  Ah, man that is so lame.
#
# Orogin line: Ses03M_impro03_F004 [029.9675-034.1700]: Are you serious [GARBAGE] man?
#
# May be file is so short:  auditary_emotion_recognition/IEMOCAP_full_release/Session2/sentences/wav/Ses02F_impro06/Ses02F_impro06_M013.wav
# Orogin line: Ses03M_impro03_M005 [028.4206-035.8916]: Get the big pizza--and I put it in the pizza and she ate so [GARBAGE]
#
# Orogin line: Ses03M_impro03_F005 [035.5900-041.3575]: Oh like that one movie.  What's that one movie I just saw? No.  Where she like swallows the...
#
# Orogin line: Ses03M_impro03_M006 [037.5283-040.8402]: American Pie? Ah.
#
# Orogin line: Ses03M_impro03_F006 [041.3825-047.1559]: oh, I don't remember.  Everybody Says I Love You with Drew Barrymore...no you haven't seen it?  Okay.
#
# Orogin line: Ses03M_impro03_M007 [045.7500-052.7925]: Yeah.  It sounds like a chick flick. Anyways so, she gets the ring and she goes,
#
# Orogin line: Ses03M_impro03_F007 [047.2875-049.4858]: Yeah.  Well...
#
# Orogin line: Ses03M_impro03_M008 [052.9100-058.3046]: Barry what's this?  And I go, I don't know.  She goes--
#
# Orogin line: Ses03M_impro03_F008 [056.2058-058.8630]: She calls you Barry?
#
# Orogin line: Ses03M_impro03_M009 [058.3600-060.1425]: That's my name.
#
# Orogin line: Ses03M_impro03_F009 [059.5725-064.0950]: Oh, okay.  Well I call you Joe cause you're middle name Joseph.
#
# Orogin line: Ses03M_impro03_M010 [063.6550-071.4500]: Barry Joe, B.J. [LAUGHTER] Oh you dirty, dirty girl. you're so dirty.
#
# Orogin line: Ses03M_impro03_F010 [064.9400-070.2428]: [LAUGHTER] So nasty. No you... dirty me?
#
# Orogin line: Ses03M_impro03_F011 [070.8012-072.2069]: Okay.
#
# Orogin line: Ses03M_impro03_M011 [071.6292-079.4853]: Ah...Anyways, so she took the ring and she goes, is this real?  So I was like, of course--
#
# Orogin line: Ses03M_impro03_M012 [079.5700-082.0655]: Sara and I--
#
# Orogin line: Ses03M_impro03_F012 [081.5456-086.9756]: She actually asked if it was real?  I would've probably asked the same thing considering you were in Chuck E. Cheese.
#
# Orogin line: Ses03M_impro03_M013 [086.2875-089.7868]: Come on. It was her birthday.
#
# Orogin line: Ses03M_impro03_F013 [087.0333-088.9203]: Because of Chuck E. Cheese?
#
# Orogin line: Ses03M_impro03_F014 [089.1050-092.6173]: Oh, man. How old are you? Five?
#
# Orogin line: Ses03M_impro03_M014 [090.0757-094.3118]: She wanted...she always wants something spontaneous.
#
# Orogin line: Ses03M_impro03_F015 [092.8676-095.6211]: Yeah.  That's, you know, okay.
#
# Orogin line: Ses03M_impro03_M015 [094.5043-100.2616]: I couldn't, I couldn't afford the Red Lobster. [LAUGHTER] What anyway?
#
# Orogin line: Ses03M_impro03_F016 [096.5950-106.0767]: Oh god! You are damn cheap, cheap, cheap. Anyways, moving on. It's not like you're poor.  I mean your dad makes... okey
#
# Orogin line: Ses03M_impro03_M016 [103.4965-106.2307]: So Okay then and.
#
# Orogin line: Ses03M_impro03_M017 [106.2307-109.6004]: I got all the character animals to do a conga line,
#
# Orogin line: Ses03M_impro03_M018 [109.6004-115.3577]: dim down the lights and uh, I got on one of the tables pulled her up.
#
# Orogin line: Ses03M_impro03_F017 [112.7967-115.3962]: You had the mouse?
#
# Orogin line: Ses03M_impro03_F018 [115.4540-119.5553]: Isn't it a rat?  It's a rat.  Chuck E. Cheese?
#
# Orogin line: Ses03M_impro03_M019 [115.4050-117.8650]: Yeah.
#
# Orogin line: Ses03M_impro03_M020 [119.4205-127.3325]: Chucky...I don't know.  I don't know. Anyways, I pull her up and I go, I go Sarah
#
# Orogin line: Ses03M_impro03_F019 [121.1750-124.6300]: Okay. [LAUGHTER]
#
# Orogin line: Ses03M_impro03_M021 [127.4150-136.4228]: You're my guiding light, then they put on that song the I've had the time of my life, that song.
#
# Orogin line: Ses03M_impro03_F020 [129.1150-132.7400]: Oh my God.
#
# Orogin line: Ses03M_impro03_F021 [134.5551-138.1400]: Okay, that is really cheesy Joe.
#
# Orogin line: Ses03M_impro03_M022 [136.6731-141.3521]: And I go, I want to spend the rest of my life with you.
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# <ipython-input-1-855480abf616> in <module>()
#     352
#     353         ##Get input, normalize input, get output
# --> 354         input, output, transcript = createInput_Output()
#     355
#     356         transcript = np.array(transcript)
#
# <ipython-input-1-855480abf616> in createInput_Output()
#     328     # Multi processing
#     329     with Pool(processes=8) as pool:
# --> 330          in_out = pool.starmap(parallel_task, ds)
#     331
#     332     r = []
#
# /usr/lib64/python3.6/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     272         `func` and (a, b) becomes func(a, b).
#     273         '''
# --> 274         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     275
#     276     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# /usr/lib64/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib64/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib64/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib64/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
