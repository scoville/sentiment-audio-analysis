# %% [markdown]
# # Playing around

# %%
AUDIO_FILES_PATH = "auditary_emotion_recognition/data_interview/Audio/Audio"
AUDIO_LABEL_PATH = "auditary_emotion_recognition/data_interview/Labels/turker_scores_full_interview.csv"

# %%
import pickle
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import backend as K
import tensorflow as tf
from keras.utils.np_utils import to_categorical
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
import sys
sys.path.insert(0, "../")
from acousticFeatures import getAllFeatures
import parselmouth 
import numpy as np
from pydub import AudioSegment
from IPython.display import Audio
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc

def parse_metric(confusion_matrix):
    FP = confusion_matrix.sum(axis=0) - np.diag(confusion_matrix)  
    FN = confusion_matrix.sum(axis=1) - np.diag(confusion_matrix)
    TP = np.diag(confusion_matrix)
    TN = confusion_matrix.sum() - (FP + FN + TP)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)
    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)
    
    return {'FP': FP, 'FN': FN, 'TP':TP, 'TN':TN, 'TPR': TPR, 'TNR': TNR, 'PPV' : PPV, 'NPV' :NPV, 'FPR': FPR, 'FNR': FNR,
           'FDR': FDR, 'ACC':ACC}



max_acoustic_features = pickle.load(open('processed-data/max_acoustic_features.obj', 'rb'))
min_acoustic_features = pickle.load(open('processed-data/min_acoustic_features.obj', 'rb'))
mean_acoustic_features = pickle.load(open('processed-data/mean_acoustic_features.obj', 'rb'))
std_acoustic_features = pickle.load(open('processed-data/std_acoustic_features.obj', 'rb'))

#Load model
clf = MLPClassifier(hidden_layer_sizes= (100,), learning_rate_init= 0.0001)
clf = pickle.load(open("model/model_classification.sav", 'rb'))
model_regression_arouse = pickle.load(open("model/model_regression_arouse.sav", 'rb'))

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
from os.path import isfile

df = pd.read_csv(AUDIO_LABEL_PATH)
df_exc = df[['Participant','Excited']]
df_exc_groupby_person = df_exc.groupby(['Participant'])
df_exc_groupby_person.groups.keys()

person_excValues_tuple = [(k, df_exc_groupby_person.get_group(k).iloc[-1][1]) for k in df_exc_groupby_person.groups]

# [(key, output)]
output = person_excValues_tuple

# %%
def create_input(key):
    sound1 = AudioSegment.from_file(AUDIO_FILES_PATH + "/" + key +".wav", frame_rate= 44100)
    segment_length = 2000
    results = []
    input = []
    for i, chunk in enumerate(sound1[::segment_length]):
        left, right = chunk.split_to_mono()
        sound = parselmouth.Sound(left.get_array_of_samples())

        # Todo
        acoustic_features = np.array(getAllFeatures(sound))
        if(acoustic_features is not None and len(acoustic_features) > 10):
            acoustic_features = acoustic_features[1:]
            normalized_acoustic_features = (acoustic_features - min_acoustic_features[1:]) / (max_acoustic_features[1:] - min_acoustic_features[1:])
            input.append(normalized_acoustic_features)
      
    input = np.array(input)
    col_mean = np.nanmean(input, axis=0)
    inds = np.where(np.isnan(input))

    #Place column means in the indices. Align the arrays using take
    input[inds] = np.take(col_mean, inds[1])

    
    
    results = np.array(clf.predict(np.array(input)))
    print("done!")
    return  (key, np.sum(results) / len(results))


input = []
for e in output:
    input.append(create_input(e[0]))

print("Finish create input")
pickle.dump(input, open('processed-data/input-interview.obj', 'wb'))
# Out:
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 14:59:01 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2146 Pascal
#    Maximum: 1893 Pascal
#    Mean: -0.035671875 Pascal
#    Root-mean-square: 80.0457422 Pascal
# Total energy: 27895.8187 Pascal² sec (energy in air: 69.7395467 Joule/m²)
# Mean power (intensity) in air: 16.0183021 Watt/m² = 132 dB
# Standard deviation in channel 1: 80.0459427 Pascal
#
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:02:17 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -264 Pascal
#    Maximum: 262 Pascal
#    Mean: -0.0880989583 Pascal
#    Root-mean-square: 62.3363593 Pascal
# Total energy: 16917.8632 Pascal² sec (energy in air: 42.2946579 Joule/m²)
# Mean power (intensity) in air: 9.71455423 Watt/m² = 129.9 dB
# Standard deviation in channel 1: 62.3364594 Pascal
#
# done!
# C:\Users\THEDE\AppData\Roaming\Python\Python35\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# C:\Users\THEDE\AppData\Roaming\Python\Python35\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\THEDE\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# C:\Users\THEDE\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:4291: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:03:24 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.0710204081632653 seconds
#    Total duration: 1.0710204081632653 seconds
# Time sampling:
#    Number of samples: 47232
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -247 Pascal
#    Maximum: 288 Pascal
#    Mean: 0.0366912263 Pascal
#    Root-mean-square: 72.5252124 Pascal
# Total energy: 5633.46714 Pascal² sec (energy in air: 14.0836679 Joule/m²)
# Mean power (intensity) in air: 13.1497661 Watt/m² = 131.2 dB
# Standard deviation in channel 1: 72.5259709 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:03:46 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -703 Pascal
#    Maximum: 728 Pascal
#    Mean: -0.135536458 Pascal
#    Root-mean-square: 76.597297 Pascal
# Total energy: 25544.0366 Pascal² sec (energy in air: 63.8600914 Joule/m²)
# Mean power (intensity) in air: 14.6678648 Watt/m² = 131.7 dB
# Standard deviation in channel 1: 76.5973765 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:03:54 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.3657142857142857 seconds
#    Total duration: 0.3657142857142857 seconds
# Time sampling:
#    Number of samples: 16128
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -558 Pascal
#    Maximum: 545 Pascal
#    Mean: 0.562624008 Pascal
#    Root-mean-square: 111.149983 Pascal
# Total energy: 4518.15088 Pascal² sec (energy in air: 11.2953772 Joule/m²)
# Mean power (intensity) in air: 30.8857971 Watt/m² = 134.9 dB
# Standard deviation in channel 1: 111.152005 Pascal
#
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:08:29 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.008707482993197279 seconds
#    Total duration: 0.008707482993197279 seconds
# Time sampling:
#    Number of samples: 384
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -215 Pascal
#    Maximum: 187 Pascal
#    Mean: 27.09375 Pascal
#    Root-mean-square: 85.5469839 Pascal
# Total energy: 63.7238549 Pascal² sec (energy in air: 0.159309637 Joule/m²)
# Mean power (intensity) in air: 18.2957161 Watt/m² = 132.6 dB
# Standard deviation in channel 1: 81.249039 Pascal
#
# done!
# done!
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:12:56 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -873 Pascal
#    Maximum: 837 Pascal
#    Mean: -0.00994270833 Pascal
#    Root-mean-square: 65.1288198 Pascal
# Total energy: 18467.5403 Pascal² sec (energy in air: 46.1688509 Joule/m²)
# Mean power (intensity) in air: 10.6044079 Watt/m² = 130.3 dB
# Standard deviation in channel 1: 65.1289887 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:14:53 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 2.1681632653061222 seconds
#    Total duration: 2.1681632653061222 seconds
# Time sampling:
#    Number of samples: 95616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -267 Pascal
#    Maximum: 288 Pascal
#    Mean: -0.0763993474 Pascal
#    Root-mean-square: 57.8304674 Pascal
# Total energy: 7251.12492 Pascal² sec (energy in air: 18.1278123 Joule/m²)
# Mean power (intensity) in air: 8.36090741 Watt/m² = 129.2 dB
# Standard deviation in channel 1: 57.8307194 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:15:26 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2220 Pascal
#    Maximum: 2599 Pascal
#    Mean: 0.0261875 Pascal
#    Root-mean-square: 137.473775 Pascal
# Total energy: 82281.5291 Pascal² sec (energy in air: 205.703823 Joule/m²)
# Mean power (intensity) in air: 47.2475968 Watt/m² = 136.7 dB
# Standard deviation in channel 1: 137.47413 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:15:40 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -823 Pascal
#    Maximum: 1128 Pascal
#    Mean: -0.0844166667 Pascal
#    Root-mean-square: 69.9971302 Pascal
# Total energy: 21331.5842 Pascal² sec (energy in air: 53.3289604 Joule/m²)
# Mean power (intensity) in air: 12.2489956 Watt/m² = 130.9 dB
# Standard deviation in channel 1: 69.9972616 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:17:11 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2249 Pascal
#    Maximum: 2353 Pascal
#    Mean: 0.00278645833 Pascal
#    Root-mean-square: 67.8051804 Pascal
# Total energy: 20016.5115 Pascal² sec (energy in air: 50.0412787 Joule/m²)
# Mean power (intensity) in air: 11.4938562 Watt/m² = 130.6 dB
# Standard deviation in channel 1: 67.8053569 Pascal
#
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:20:23 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1071 Pascal
#    Maximum: 1187 Pascal
#    Mean: -0.142921875 Pascal
#    Root-mean-square: 77.0221824 Pascal
# Total energy: 25828.2082 Pascal² sec (energy in air: 64.5705206 Joule/m²)
# Mean power (intensity) in air: 14.8310414 Watt/m² = 131.7 dB
# Standard deviation in channel 1: 77.0222504 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:20:49 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.008707482993197279 seconds
#    Total duration: 0.008707482993197279 seconds
# Time sampling:
#    Number of samples: 384
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -894 Pascal
#    Maximum: 584 Pascal
#    Mean: -58.5286458 Pascal
#    Root-mean-square: 304.979128 Pascal
# Total energy: 809.902744 Pascal² sec (energy in air: 2.02475686 Joule/m²)
# Mean power (intensity) in air: 232.530671 Watt/m² = 143.7 dB
# Standard deviation in channel 1: 299.700807 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:21:12 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2785 Pascal
#    Maximum: 2476 Pascal
#    Mean: -0.128067708 Pascal
#    Root-mean-square: 101.568009 Pascal
# Total energy: 44913.4608 Pascal² sec (energy in air: 112.283652 Joule/m²)
# Mean power (intensity) in air: 25.7901513 Watt/m² = 134.1 dB
# Standard deviation in channel 1: 101.568193 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:21:42 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.5412244897959184 seconds
#    Total duration: 1.5412244897959184 seconds
# Time sampling:
#    Number of samples: 67968
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2434 Pascal
#    Maximum: 1914 Pascal
#    Mean: 0.149187853 Pascal
#    Root-mean-square: 179.870424 Pascal
# Total energy: 49863.8052 Pascal² sec (energy in air: 124.659513 Joule/m²)
# Mean power (intensity) in air: 80.8834234 Watt/m² = 139.1 dB
# Standard deviation in channel 1: 179.871685 Pascal
#
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:24:59 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -532 Pascal
#    Maximum: 526 Pascal
#    Mean: -0.0530885417 Pascal
#    Root-mean-square: 65.5255122 Pascal
# Total energy: 18693.1929 Pascal² sec (energy in air: 46.7329824 Joule/m²)
# Mean power (intensity) in air: 10.7339819 Watt/m² = 130.3 dB
# Standard deviation in channel 1: 65.5256614 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:25:00 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -283 Pascal
#    Maximum: 332 Pascal
#    Mean: -0.0524791667 Pascal
#    Root-mean-square: 67.9198694 Pascal
# Total energy: 20084.2826 Pascal² sec (energy in air: 50.2107065 Joule/m²)
# Mean power (intensity) in air: 11.5327716 Watt/m² = 130.6 dB
# Standard deviation in channel 1: 67.920026 Pascal
#
# done!
# done!
# done!
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:29:19 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1075 Pascal
#    Maximum: 799 Pascal
#    Mean: -0.0537135417 Pascal
#    Root-mean-square: 64.7429741 Pascal
# Total energy: 18249.3723 Pascal² sec (energy in air: 45.6234307 Joule/m²)
# Mean power (intensity) in air: 10.4791317 Watt/m² = 130.2 dB
# Standard deviation in channel 1: 64.7431204 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:29:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -427 Pascal
#    Maximum: 417 Pascal
#    Mean: -0.0369895833 Pascal
#    Root-mean-square: 86.071367 Pascal
# Total energy: 32253.737 Pascal² sec (energy in air: 80.6343425 Joule/m²)
# Mean power (intensity) in air: 18.5207005 Watt/m² = 132.7 dB
# Standard deviation in channel 1: 86.0715832 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:30:55 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 3.2565986394557824 seconds
#    Total duration: 3.2565986394557824 seconds
# Time sampling:
#    Number of samples: 143616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -531 Pascal
#    Maximum: 551 Pascal
#    Mean: -0.084795566 Pascal
#    Root-mean-square: 63.9312517 Pascal
# Total energy: 13310.3861 Pascal² sec (energy in air: 33.2759652 Joule/m²)
# Mean power (intensity) in air: 10.2180124 Watt/m² = 130.1 dB
# Standard deviation in channel 1: 63.9314181 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:31:39 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -272 Pascal
#    Maximum: 269 Pascal
#    Mean: 0.02640625 Pascal
#    Root-mean-square: 59.7774322 Pascal
# Total energy: 15557.4047 Pascal² sec (energy in air: 38.8935118 Joule/m²)
# Mean power (intensity) in air: 8.93335349 Watt/m² = 129.5 dB
# Standard deviation in channel 1: 59.777582 Pascal
#
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:33:30 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -290 Pascal
#    Maximum: 306 Pascal
#    Mean: 0.0134270833 Pascal
#    Root-mean-square: 69.3171015 Pascal
# Total energy: 20919.1208 Pascal² sec (energy in air: 52.297802 Joule/m²)
# Mean power (intensity) in air: 12.0121514 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 69.3172807 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:34:13 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.0797278911564625 seconds
#    Total duration: 1.0797278911564625 seconds
# Time sampling:
#    Number of samples: 47616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -246 Pascal
#    Maximum: 260 Pascal
#    Mean: -0.321299563 Pascal
#    Root-mean-square: 64.765146 Pascal
# Total energy: 4528.94469 Pascal² sec (energy in air: 11.3223617 Joule/m²)
# Mean power (intensity) in air: 10.4863103 Watt/m² = 130.2 dB
# Standard deviation in channel 1: 64.765029 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:34:56 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 3.2565986394557824 seconds
#    Total duration: 3.2565986394557824 seconds
# Time sampling:
#    Number of samples: 143616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1599 Pascal
#    Maximum: 1799 Pascal
#    Mean: -0.133613246 Pascal
#    Root-mean-square: 69.3761271 Pascal
# Total energy: 15674.1623 Pascal² sec (energy in air: 39.1854058 Joule/m²)
# Mean power (intensity) in air: 12.0326175 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 69.3762399 Pascal
#
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:38:09 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.0797278911564625 seconds
#    Total duration: 1.0797278911564625 seconds
# Time sampling:
#    Number of samples: 47616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -998 Pascal
#    Maximum: 949 Pascal
#    Mean: -0.0831023185 Pascal
#    Root-mean-square: 117.896323 Pascal
# Total energy: 15007.7242 Pascal² sec (energy in air: 37.5193106 Joule/m²)
# Mean power (intensity) in air: 34.7488575 Watt/m² = 135.4 dB
# Standard deviation in channel 1: 117.897532 Pascal
#
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:39:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -331 Pascal
#    Maximum: 300 Pascal
#    Mean: -0.0985677083 Pascal
#    Root-mean-square: 74.3832945 Pascal
# Total energy: 24088.7053 Pascal² sec (energy in air: 60.2217633 Joule/m²)
# Mean power (intensity) in air: 13.8321863 Watt/m² = 131.4 dB
# Standard deviation in channel 1: 74.3834229 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:39:30 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -401 Pascal
#    Maximum: 377 Pascal
#    Mean: -0.046484375 Pascal
#    Root-mean-square: 100.846952 Pascal
# Total energy: 44278.0196 Pascal² sec (energy in air: 110.695049 Joule/m²)
# Mean power (intensity) in air: 25.4252691 Watt/m² = 134.1 dB
# Standard deviation in channel 1: 100.847203 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:39:37 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -278 Pascal
#    Maximum: 269 Pascal
#    Mean: -0.0608020833 Pascal
#    Root-mean-square: 68.3150272 Pascal
# Total energy: 20318.6632 Pascal² sec (energy in air: 50.7966579 Joule/m²)
# Mean power (intensity) in air: 11.6673574 Watt/m² = 130.7 dB
# Standard deviation in channel 1: 68.3151781 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:40:39 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -16065 Pascal
#    Maximum: 12930 Pascal
#    Mean: -0.084265625 Pascal
#    Root-mean-square: 160.953492 Pascal
# Total energy: 112788.143 Pascal² sec (energy in air: 281.970356 Joule/m²)
# Mean power (intensity) in air: 64.7650662 Watt/m² = 138.1 dB
# Standard deviation in channel 1: 160.953889 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:40:41 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -4894 Pascal
#    Maximum: 4009 Pascal
#    Mean: -0.0202447917 Pascal
#    Root-mean-square: 80.9116634 Pascal
# Total energy: 28502.6276 Pascal² sec (energy in air: 71.256569 Joule/m²)
# Mean power (intensity) in air: 16.3667432 Watt/m² = 132.1 dB
# Standard deviation in channel 1: 80.9118716 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:40:44 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -491 Pascal
#    Maximum: 438 Pascal
#    Mean: -0.000536458333 Pascal
#    Root-mean-square: 65.1179849 Pascal
# Total energy: 18461.3963 Pascal² sec (energy in air: 46.1534908 Joule/m²)
# Mean power (intensity) in air: 10.6008799 Watt/m² = 130.3 dB
# Standard deviation in channel 1: 65.1181545 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:40:47 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1143 Pascal
#    Maximum: 1084 Pascal
#    Mean: -0.127838542 Pascal
#    Root-mean-square: 95.9217402 Pascal
# Total energy: 40058.6895 Pascal² sec (energy in air: 100.146724 Joule/m²)
# Mean power (intensity) in air: 23.0024506 Watt/m² = 133.6 dB
# Standard deviation in channel 1: 95.9219048 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:41:48 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -9044 Pascal
#    Maximum: 15088 Pascal
#    Mean: -0.130598958 Pascal
#    Root-mean-square: 222.674937 Pascal
# Total energy: 215876.474 Pascal² sec (energy in air: 539.691185 Joule/m²)
# Mean power (intensity) in air: 123.960319 Watt/m² = 140.9 dB
# Standard deviation in channel 1: 222.675479 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:41:51 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.1306122448979592 seconds
#    Total duration: 0.1306122448979592 seconds
# Time sampling:
#    Number of samples: 5760
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: 0 Pascal
#    Maximum: 0 Pascal
#    Mean: 0 Pascal
#    Root-mean-square: 0 Pascal
# Total energy: 0 Pascal² sec (energy in air: 0 Joule/m²)
# Mean power (intensity) in air: 0 Watt/m²
# Standard deviation in channel 1: 0 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:42:04 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -866 Pascal
#    Maximum: 657 Pascal
#    Mean: -0.112625 Pascal
#    Root-mean-square: 69.6574349 Pascal
# Total energy: 21125.0427 Pascal² sec (energy in air: 52.8126067 Joule/m²)
# Mean power (intensity) in air: 12.1303956 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 69.6575253 Pascal
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:43:19 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 2.1681632653061222 seconds
#    Total duration: 2.1681632653061222 seconds
# Time sampling:
#    Number of samples: 95616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -341 Pascal
#    Maximum: 319 Pascal
#    Mean: -0.00856551205 Pascal
#    Root-mean-square: 83.2581617 Pascal
# Total energy: 15029.5375 Pascal² sec (energy in air: 37.5738438 Joule/m²)
# Mean power (intensity) in air: 17.3298037 Watt/m² = 132.4 dB
# Standard deviation in channel 1: 83.2585966 Pascal
#
# done!
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:45:23 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -461 Pascal
#    Maximum: 459 Pascal
#    Mean: -0.00592708333 Pascal
#    Root-mean-square: 62.4216569 Pascal
# Total energy: 16964.1937 Pascal² sec (energy in air: 42.4104844 Joule/m²)
# Mean power (intensity) in air: 9.74115812 Watt/m² = 129.9 dB
# Standard deviation in channel 1: 62.4218192 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:46:46 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -486 Pascal
#    Maximum: 404 Pascal
#    Mean: -0.029375 Pascal
#    Root-mean-square: 54.0509991 Pascal
# Total energy: 12719.5015 Pascal² sec (energy in air: 31.7987537 Joule/m²)
# Mean power (intensity) in air: 7.30377625 Watt/m² = 128.6 dB
# Standard deviation in channel 1: 54.0511318 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:47:24 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.008707482993197279 seconds
#    Total duration: 0.008707482993197279 seconds
# Time sampling:
#    Number of samples: 384
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -220 Pascal
#    Maximum: 131 Pascal
#    Mean: -33.2864583 Pascal
#    Root-mean-square: 79.423476 Pascal
# Total energy: 54.9275737 Pascal² sec (energy in air: 0.137318934 Joule/m²)
# Mean power (intensity) in air: 15.7702214 Watt/m² = 132 dB
# Standard deviation in channel 1: 72.2057998 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:47:30 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1404 Pascal
#    Maximum: 1205 Pascal
#    Mean: -0.0342239583 Pascal
#    Root-mean-square: 79.641372 Pascal
# Total energy: 27614.6857 Pascal² sec (energy in air: 69.0367143 Joule/m²)
# Mean power (intensity) in air: 15.8568703 Watt/m² = 132 dB
# Standard deviation in channel 1: 79.641572 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:47:47 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -902 Pascal
#    Maximum: 1174 Pascal
#    Mean: -0.0557916667 Pascal
#    Root-mean-square: 50.3878377 Pascal
# Total energy: 11053.8631 Pascal² sec (energy in air: 27.6346578 Joule/m²)
# Mean power (intensity) in air: 6.34733547 Watt/m² = 128 dB
# Standard deviation in channel 1: 50.387938 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:47:58 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -604 Pascal
#    Maximum: 553 Pascal
#    Mean: -0.0763958333 Pascal
#    Root-mean-square: 52.0425261 Pascal
# Total energy: 11791.7802 Pascal² sec (energy in air: 29.4794506 Joule/m²)
# Mean power (intensity) in air: 6.7710613 Watt/m² = 128.3 dB
# Standard deviation in channel 1: 52.0426055 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:47:58 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 2.17687074829932 seconds
#    Total duration: 2.17687074829932 seconds
# Time sampling:
#    Number of samples: 96000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -290 Pascal
#    Maximum: 538 Pascal
#    Mean: 0.02090625 Pascal
#    Root-mean-square: 53.3813009 Pascal
# Total energy: 6203.13095 Pascal² sec (energy in air: 15.5078274 Joule/m²)
# Mean power (intensity) in air: 7.1239082 Watt/m² = 128.5 dB
# Standard deviation in channel 1: 53.3815748 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:03 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1452 Pascal
#    Maximum: 1250 Pascal
#    Mean: -0.04946875 Pascal
#    Root-mean-square: 79.98761 Pascal
# Total energy: 27855.3154 Pascal² sec (energy in air: 69.6382884 Joule/m²)
# Mean power (intensity) in air: 15.9950444 Watt/m² = 132 dB
# Standard deviation in channel 1: 79.987803 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:03 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -5424 Pascal
#    Maximum: 4585 Pascal
#    Mean: -0.0293072917 Pascal
#    Root-mean-square: 109.716403 Pascal
# Total energy: 52408.9863 Pascal² sec (energy in air: 131.022466 Joule/m²)
# Mean power (intensity) in air: 30.0942226 Watt/m² = 134.8 dB
# Standard deviation in channel 1: 109.716685 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:04 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2774 Pascal
#    Maximum: 3320 Pascal
#    Mean: -0.05390625 Pascal
#    Root-mean-square: 131.919615 Pascal
# Total energy: 75767.2268 Pascal² sec (energy in air: 189.418067 Joule/m²)
# Mean power (intensity) in air: 43.5069623 Watt/m² = 136.4 dB
# Standard deviation in channel 1: 131.919948 Pascal
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:04 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2106 Pascal
#    Maximum: 2304 Pascal
#    Mean: -0.087921875 Pascal
#    Root-mean-square: 69.1359965 Pascal
# Total energy: 20809.9527 Pascal² sec (energy in air: 52.0248818 Joule/m²)
# Mean power (intensity) in air: 11.949465 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 69.1361207 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:05 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -294 Pascal
#    Maximum: 369 Pascal
#    Mean: 0.0150625 Pascal
#    Root-mean-square: 59.9210455 Pascal
# Total energy: 15632.2468 Pascal² sec (energy in air: 39.0806171 Joule/m²)
# Mean power (intensity) in air: 8.97632924 Watt/m² = 129.5 dB
# Standard deviation in channel 1: 59.9211997 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:48:05 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2161 Pascal
#    Maximum: 2104 Pascal
#    Mean: -0.00352083333 Pascal
#    Root-mean-square: 74.9960641 Pascal
# Total energy: 24487.2256 Pascal² sec (energy in air: 61.2180641 Joule/m²)
# Mean power (intensity) in air: 14.0610241 Watt/m² = 131.5 dB
# Standard deviation in channel 1: 74.9962594 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:49:10 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2016 Pascal
#    Maximum: 1991 Pascal
#    Mean: -0.0386979167 Pascal
#    Root-mean-square: 107.690547 Pascal
# Total energy: 50491.4458 Pascal² sec (energy in air: 126.228615 Joule/m²)
# Mean power (intensity) in air: 28.9931349 Watt/m² = 134.6 dB
# Standard deviation in channel 1: 107.690821 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:49:10 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2010 Pascal
#    Maximum: 2604 Pascal
#    Mean: -0.0586145833 Pascal
#    Root-mean-square: 58.3046294 Pascal
# Total energy: 14800.2386 Pascal² sec (energy in air: 37.0005966 Joule/m²)
# Mean power (intensity) in air: 8.49857453 Watt/m² = 129.3 dB
# Standard deviation in channel 1: 58.3047518 Pascal
#
# done!
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:50:57 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -825 Pascal
#    Maximum: 829 Pascal
#    Mean: -0.007734375 Pascal
#    Root-mean-square: 62.6051805 Pascal
# Total energy: 17064.092 Pascal² sec (energy in air: 42.6602299 Joule/m²)
# Mean power (intensity) in air: 9.79852155 Watt/m² = 129.9 dB
# Standard deviation in channel 1: 62.605343 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:50:57 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -524 Pascal
#    Maximum: 543 Pascal
#    Mean: -0.0593541667 Pascal
#    Root-mean-square: 61.5494992 Pascal
# Total energy: 16493.4568 Pascal² sec (energy in air: 41.233642 Joule/m²)
# Mean power (intensity) in air: 9.47085214 Watt/m² = 129.8 dB
# Standard deviation in channel 1: 61.5496309 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:52:44 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -24854 Pascal
#    Maximum: 23456 Pascal
#    Mean: 0.195041667 Pascal
#    Root-mean-square: 674.757746 Pascal
# Total energy: 1982249.86 Pascal² sec (energy in air: 4955.62466 Joule/m²)
# Mean power (intensity) in air: 1138.24504 Watt/m² = 150.6 dB
# Standard deviation in channel 1: 674.759475 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:52:44 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.4440816326530612 seconds
#    Total duration: 0.4440816326530612 seconds
# Time sampling:
#    Number of samples: 19584
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -450 Pascal
#    Maximum: 486 Pascal
#    Mean: -2.30443219 Pascal
#    Root-mean-square: 41.5524525 Pascal
# Total energy: 766.75415 Pascal² sec (energy in air: 1.91688537 Joule/m²)
# Mean power (intensity) in air: 4.31651578 Watt/m² = 126.4 dB
# Standard deviation in channel 1: 41.4895626 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:53:26 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -977 Pascal
#    Maximum: 1377 Pascal
#    Mean: 0.00686979167 Pascal
#    Root-mean-square: 63.72623 Pascal
# Total energy: 17680.6852 Pascal² sec (energy in air: 44.2017131 Joule/m²)
# Mean power (intensity) in air: 10.152581 Watt/m² = 130.1 dB
# Standard deviation in channel 1: 63.7263956 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:53:26 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -917 Pascal
#    Maximum: 1092 Pascal
#    Mean: -0.0333697917 Pascal
#    Root-mean-square: 61.8234384 Pascal
# Total energy: 16640.5988 Pascal² sec (energy in air: 41.601497 Joule/m²)
# Mean power (intensity) in air: 9.55534384 Watt/m² = 129.8 dB
# Standard deviation in channel 1: 61.8235904 Pascal
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:53:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1107 Pascal
#    Maximum: 1254 Pascal
#    Mean: -0.0313385417 Pascal
#    Root-mean-square: 63.2277497 Pascal
# Total energy: 17405.1628 Pascal² sec (energy in air: 43.512907 Joule/m²)
# Mean power (intensity) in air: 9.99437082 Watt/m² = 130 dB
# Standard deviation in channel 1: 63.2279066 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:54:19 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -16400 Pascal
#    Maximum: 11049 Pascal
#    Mean: -0.0878333333 Pascal
#    Root-mean-square: 289.36971 Pascal
# Total energy: 364559.801 Pascal² sec (energy in air: 911.399502 Joule/m²)
# Mean power (intensity) in air: 209.337073 Watt/m² = 143.2 dB
# Standard deviation in channel 1: 289.370451 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:54:24 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -3127 Pascal
#    Maximum: 3808 Pascal
#    Mean: -0.01096875 Pascal
#    Root-mean-square: 109.003186 Pascal
# Total energy: 51729.8264 Pascal² sec (energy in air: 129.324566 Joule/m²)
# Mean power (intensity) in air: 29.7042363 Watt/m² = 134.7 dB
# Standard deviation in channel 1: 109.003469 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:54:25 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -814 Pascal
#    Maximum: 1572 Pascal
#    Mean: -0.0506145833 Pascal
#    Root-mean-square: 66.2357353 Pascal
# Total energy: 19100.6155 Pascal² sec (energy in air: 47.7515388 Joule/m²)
# Mean power (intensity) in air: 10.9679316 Watt/m² = 130.4 dB
# Standard deviation in channel 1: 66.2358884 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:54:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1142 Pascal
#    Maximum: 1622 Pascal
#    Mean: -0.015296875 Pascal
#    Root-mean-square: 88.5925464 Pascal
# Total energy: 34170.9465 Pascal² sec (energy in air: 85.4273663 Joule/m²)
# Mean power (intensity) in air: 19.6215982 Watt/m² = 132.9 dB
# Standard deviation in channel 1: 88.5927758 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 15:54:29 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
# ...
# Mean power (intensity) in air: 10.5634609 Watt/m² = 130.2 dB
# Standard deviation in channel 1: 65.0031257 Pascal
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:42:58 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.0797278911564625 seconds
#    Total duration: 1.0797278911564625 seconds
# Time sampling:
#    Number of samples: 47616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -543 Pascal
#    Maximum: 524 Pascal
#    Mean: -0.239751344 Pascal
#    Root-mean-square: 91.4237986 Pascal
# Total energy: 9024.70145 Pascal² sec (energy in air: 22.5617536 Joule/m²)
# Mean power (intensity) in air: 20.8957774 Watt/m² = 133.2 dB
# Standard deviation in channel 1: 91.4244442 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:43:19 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -648 Pascal
#    Maximum: 474 Pascal
#    Mean: -0.07396875 Pascal
#    Root-mean-square: 55.5335604 Pascal
# Total energy: 13426.8357 Pascal² sec (energy in air: 33.5670893 Joule/m²)
# Mean power (intensity) in air: 7.70994083 Watt/m² = 128.9 dB
# Standard deviation in channel 1: 55.5336558 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:43:26 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -209 Pascal
#    Maximum: 237 Pascal
#    Mean: -0.0355885417 Pascal
#    Root-mean-square: 52.3682078 Pascal
# Total energy: 11939.8278 Pascal² sec (energy in air: 29.8495694 Joule/m²)
# Mean power (intensity) in air: 6.85607298 Watt/m² = 128.4 dB
# Standard deviation in channel 1: 52.3683321 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:43:26 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -256 Pascal
#    Maximum: 210 Pascal
#    Mean: -0.0113489583 Pascal
#    Root-mean-square: 51.8478107 Pascal
# Total energy: 11703.7082 Pascal² sec (energy in air: 29.2592705 Joule/m²)
# Mean power (intensity) in air: 6.72048868 Watt/m² = 128.3 dB
# Standard deviation in channel 1: 51.8479445 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:43:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -306 Pascal
#    Maximum: 363 Pascal
#    Mean: -0.0561614583 Pascal
#    Root-mean-square: 53.6813444 Pascal
# Total energy: 12546.1191 Pascal² sec (energy in air: 31.3652978 Joule/m²)
# Mean power (intensity) in air: 7.20421684 Watt/m² = 128.6 dB
# Standard deviation in channel 1: 53.6814548 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:43:38 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1183 Pascal
#    Maximum: 1336 Pascal
#    Mean: -0.0911822917 Pascal
#    Root-mean-square: 69.0296162 Pascal
# Total energy: 20745.961 Pascal² sec (energy in air: 51.8649024 Joule/m²)
# Mean power (intensity) in air: 11.9127198 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 69.0297357 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:46:18 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 0.008707482993197279 seconds
#    Total duration: 0.008707482993197279 seconds
# Time sampling:
#    Number of samples: 384
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1033 Pascal
#    Maximum: 1284 Pascal
#    Mean: 97.4166667 Pascal
#    Root-mean-square: 734.523169 Pascal
# Total energy: 4697.89855 Pascal² sec (energy in air: 11.7447464 Joule/m²)
# Mean power (intensity) in air: 1348.81072 Watt/m² = 151.3 dB
# Standard deviation in channel 1: 728.984349 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:47:33 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -821 Pascal
#    Maximum: 1058 Pascal
#    Mean: -0.0165208333 Pascal
#    Root-mean-square: 58.9116196 Pascal
# Total energy: 15110.0035 Pascal² sec (energy in air: 37.7750087 Joule/m²)
# Mean power (intensity) in air: 8.67644732 Watt/m² = 129.4 dB
# Standard deviation in channel 1: 58.9117707 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:47:33 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -15887 Pascal
#    Maximum: 16321 Pascal
#    Mean: -0.04275 Pascal
#    Root-mean-square: 234.812251 Pascal
# Total energy: 240051.345 Pascal² sec (energy in air: 600.128362 Joule/m²)
# Mean power (intensity) in air: 137.841983 Watt/m² = 141.4 dB
# Standard deviation in channel 1: 234.812859 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:47:35 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 2.3597278911564628 seconds
#    Total duration: 2.3597278911564628 seconds
# Time sampling:
#    Number of samples: 104064
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2437 Pascal
#    Maximum: 2904 Pascal
#    Mean: -0.0592135609 Pascal
#    Root-mean-square: 92.9386894 Pascal
# Total energy: 20382.3856 Pascal² sec (energy in air: 50.9559641 Joule/m²)
# Mean power (intensity) in air: 21.594 Watt/m² = 133.3 dB
# Standard deviation in channel 1: 92.9391171 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:48:29 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -423 Pascal
#    Maximum: 502 Pascal
#    Mean: -0.0815260417 Pascal
#    Root-mean-square: 72.8856836 Pascal
# Total energy: 23128.4806 Pascal² sec (energy in air: 57.8212014 Joule/m²)
# Mean power (intensity) in air: 13.2808072 Watt/m² = 131.2 dB
# Standard deviation in channel 1: 72.8858279 Pascal
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:48:46 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -4043 Pascal
#    Maximum: 5023 Pascal
#    Mean: -0.105348958 Pascal
#    Root-mean-square: 105.950324 Pascal
# Total energy: 48872.8 Pascal² sec (energy in air: 122.182 Joule/m²)
# Mean power (intensity) in air: 28.0636781 Watt/m² = 134.5 dB
# Standard deviation in channel 1: 105.950548 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:48:46 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -3167 Pascal
#    Maximum: 2906 Pascal
#    Mean: -0.066546875 Pascal
#    Root-mean-square: 140.850674 Pascal
# Total energy: 86373.4956 Pascal² sec (energy in air: 215.933739 Joule/m²)
# Mean power (intensity) in air: 49.5972807 Watt/m² = 137 dB
# Standard deviation in channel 1: 140.851025 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:48:49 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -2710 Pascal
#    Maximum: 2527 Pascal
#    Mean: -0.0638125 Pascal
#    Root-mean-square: 85.3199917 Pascal
# Total energy: 31693.0655 Pascal² sec (energy in air: 79.2326637 Joule/m²)
# Mean power (intensity) in air: 18.1987524 Watt/m² = 132.6 dB
# Standard deviation in channel 1: 85.32019 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:48:52 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -822 Pascal
#    Maximum: 899 Pascal
#    Mean: -0.0234427083 Pascal
#    Root-mean-square: 88.6294113 Pascal
# Total energy: 34199.3907 Pascal² sec (energy in air: 85.4984767 Joule/m²)
# Mean power (intensity) in air: 19.6379314 Watt/m² = 132.9 dB
# Standard deviation in channel 1: 88.629639 Pascal
#
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:50:32 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1070 Pascal
#    Maximum: 1160 Pascal
#    Mean: -0.039859375 Pascal
#    Root-mean-square: 68.9716311 Pascal
# Total energy: 20711.1223 Pascal² sec (energy in air: 51.7778057 Joule/m²)
# Mean power (intensity) in air: 11.8927148 Watt/m² = 130.8 dB
# Standard deviation in channel 1: 68.9717992 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:50:36 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -838 Pascal
#    Maximum: 602 Pascal
#    Mean: 0.0140104167 Pascal
#    Root-mean-square: 64.877989 Pascal
# Total energy: 18325.5661 Pascal² sec (energy in air: 45.8139152 Joule/m²)
# Mean power (intensity) in air: 10.5228836 Watt/m² = 130.2 dB
# Standard deviation in channel 1: 64.8781565 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:50:56 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 4.35374149659864 seconds
#    Total duration: 4.35374149659864 seconds
# Time sampling:
#    Number of samples: 192000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -547 Pascal
#    Maximum: 719 Pascal
#    Mean: -0.110557292 Pascal
#    Root-mean-square: 58.450692 Pascal
# Total energy: 14874.4855 Pascal² sec (energy in air: 37.1862138 Joule/m²)
# Mean power (intensity) in air: 8.54120848 Watt/m² = 129.3 dB
# Standard deviation in channel 1: 58.4507396 Pascal
#
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:51:30 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.6631292517006804 seconds
#    Total duration: 1.6631292517006804 seconds
# Time sampling:
#    Number of samples: 73344
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -667 Pascal
#    Maximum: 782 Pascal
#    Mean: -0.111842823 Pascal
#    Root-mean-square: 75.2876085 Pascal
# Total energy: 9426.98914 Pascal² sec (energy in air: 23.5674728 Joule/m²)
# Mean power (intensity) in air: 14.17056 Watt/m² = 131.5 dB
# Standard deviation in channel 1: 75.2880387 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:53:39 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.08843537414966 seconds
#    Total duration: 1.08843537414966 seconds
# Time sampling:
#    Number of samples: 48000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -258 Pascal
#    Maximum: 257 Pascal
#    Mean: 0.1353125 Pascal
#    Root-mean-square: 66.3290794 Pascal
# Total energy: 4788.62234 Pascal² sec (energy in air: 11.9715558 Joule/m²)
# Mean power (intensity) in air: 10.9988669 Watt/m² = 130.4 dB
# Standard deviation in channel 1: 66.3296323 Pascal
#
# done!
# done!
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 16:55:28 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 1.0797278911564625 seconds
#    Total duration: 1.0797278911564625 seconds
# Time sampling:
#    Number of samples: 47616
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1882 Pascal
#    Maximum: 1573 Pascal
#    Mean: -0.0420446909 Pascal
#    Root-mean-square: 63.0298252 Pascal
# Total energy: 4289.49855 Pascal² sec (energy in air: 10.7237464 Joule/m²)
# Mean power (intensity) in air: 9.93189716 Watt/m² = 130 dB
# Standard deviation in channel 1: 63.030473 Pascal
#
# done!
# done!
# Finish create input

# %%
input = pickle.load(open('processed-data/input-interview.obj', 'rb'))
x = []
y = []
for i in range(0, len(output)):
    x.append(input[i][1])
    y.append(output[i][1])

    
plt.scatter(x, y) 
plt.xlabel("Percentage of Excited Frame (%)")
plt.ylabel("Excited")
# Out:
# Text(0,0.5,'Excited')

# %%
split_point = np.median(y)
y_binary = [ int(e >= split_point) for e in y]

thresholds = np.linspace(0, 1.0, 50)
tpr_arr = []
fpr_arr = []
thresh_arr = [] 
for t in thresholds:
    predict_binary = np.array([int(i >= t) for i in x])
    cfm = confusion_matrix(y_binary, predict_binary)
    parse_values = parse_metric(cfm)
    tpr_arr.append(parse_values['TPR'])
    fpr_arr.append(parse_values['FPR'])
    thresh_arr.append(t)
    print("Threshold:{}, ACC:{}".format(t,parse_values['ACC'][0] ))

fpr_arr = np.asarray(fpr_arr)
tpr_arr = np.asarray(tpr_arr)
roc_auc = auc(fpr_arr[:,1], tpr_arr[:,1])
plt.plot(fpr_arr[:,1], tpr_arr[:,1], label='ROC curve (area = {0:0.2f})'
               ''.format(roc_auc),
         color='navy', linestyle=':', linewidth=4)
plt.plot([0, 1], [0, 1], 'k--')
plt.legend(loc="lower right")
plt.show();
# Out:
# Threshold:0.0, ACC:0.5
# Threshold:0.02040816326530612, ACC:0.5
# Threshold:0.04081632653061224, ACC:0.5
# Threshold:0.061224489795918366, ACC:0.5
# Threshold:0.08163265306122448, ACC:0.5072463768115942
# Threshold:0.1020408163265306, ACC:0.5217391304347826
# Threshold:0.12244897959183673, ACC:0.5217391304347826
# Threshold:0.14285714285714285, ACC:0.5217391304347826
# Threshold:0.16326530612244897, ACC:0.5217391304347826
# Threshold:0.18367346938775508, ACC:0.5217391304347826
# Threshold:0.2040816326530612, ACC:0.5289855072463768
# Threshold:0.22448979591836732, ACC:0.5362318840579711
# Threshold:0.24489795918367346, ACC:0.5507246376811594
# Threshold:0.26530612244897955, ACC:0.5579710144927537
# Threshold:0.2857142857142857, ACC:0.5579710144927537
# Threshold:0.3061224489795918, ACC:0.5652173913043478
# Threshold:0.32653061224489793, ACC:0.5869565217391305
# Threshold:0.3469387755102041, ACC:0.6014492753623188
# Threshold:0.36734693877551017, ACC:0.6086956521739131
# Threshold:0.3877551020408163, ACC:0.6086956521739131
# Threshold:0.4081632653061224, ACC:0.6231884057971014
# Threshold:0.42857142857142855, ACC:0.6304347826086957
# Threshold:0.44897959183673464, ACC:0.6376811594202898
# Threshold:0.4693877551020408, ACC:0.644927536231884
# Threshold:0.4897959183673469, ACC:0.6739130434782609
# Threshold:0.5102040816326531, ACC:0.6594202898550725
# Threshold:0.5306122448979591, ACC:0.6666666666666666
# Threshold:0.5510204081632653, ACC:0.6811594202898551
# Threshold:0.5714285714285714, ACC:0.6956521739130435
# Threshold:0.5918367346938775, ACC:0.6956521739130435
# Threshold:0.6122448979591836, ACC:0.6956521739130435
# Threshold:0.6326530612244897, ACC:0.6956521739130435
# Threshold:0.6530612244897959, ACC:0.717391304347826
# Threshold:0.673469387755102, ACC:0.717391304347826
# Threshold:0.6938775510204082, ACC:0.7246376811594203
# Threshold:0.7142857142857142, ACC:0.6884057971014492
# Threshold:0.7346938775510203, ACC:0.6666666666666666
# Threshold:0.7551020408163265, ACC:0.6594202898550725
# Threshold:0.7755102040816326, ACC:0.6521739130434783
# Threshold:0.7959183673469387, ACC:0.6304347826086957
# Threshold:0.8163265306122448, ACC:0.6159420289855072
# Threshold:0.836734693877551, ACC:0.6231884057971014
# Threshold:0.8571428571428571, ACC:0.6014492753623188
# Threshold:0.8775510204081632, ACC:0.6231884057971014
# Threshold:0.8979591836734693, ACC:0.6231884057971014
# Threshold:0.9183673469387754, ACC:0.5869565217391305
# Threshold:0.9387755102040816, ACC:0.5652173913043478
# Threshold:0.9591836734693877, ACC:0.5434782608695652
# Threshold:0.9795918367346939, ACC:0.5217391304347826
# Threshold:1.0, ACC:0.5
# C:\Users\THEDE\Miniconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\THEDE\Miniconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\THEDE\Miniconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# # Audio

# %%
frame_rate = 44100
sound1 = AudioSegment.from_file(AUDIO_FILES_PATH + "/" + "p16.wav", frame_rate= frame_rate)
segment_length = 3000
results = []
for i, chunk in enumerate(sound1[::segment_length]):
    left, right = chunk.split_to_mono()
    sound = parselmouth.Sound(left.get_array_of_samples())

    # Todo
    acoustic_features = np.array(getAllFeatures(sound))
    try:
        acoustic_features = acoustic_features[1:]
        normalized_acoustic_features = (acoustic_features - min_acoustic_features[1:]) / (max_acoustic_features[1:] - min_acoustic_features[1:])
        #print(normalized_acoustic_features)
        #print(len(normalized_acoustic_features))
        #Predict
        pre = clf.predict(np.array([normalized_acoustic_features]))
        print("predict:", pre)
        results.append((int(segment_length*i / 1000), pre))
    except:
        print("Something wrong")

    
times, predicts = zip(*results)

plt.plot(times, predicts)
# Out:
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# May be file is so short:  Object type: Sound
# Object name: <no name>
# Date: Wed Jul 18 10:55:00 2018
#
# Number of channels: 1 (mono)
# Time domain:
#    Start time: 0 seconds
#    End time: 3.2653061224489797 seconds
#    Total duration: 3.2653061224489797 seconds
# Time sampling:
#    Number of samples: 144000
#    Sampling period: 2.2675736961451248e-05 seconds
#    Sampling frequency: 44100 Hz
#    First sample centred at: 1.1337868480725624e-05 seconds
# Amplitude:
#    Minimum: -1181 Pascal
#    Maximum: 1297 Pascal
#    Mean: 0.000770833333 Pascal
#    Root-mean-square: 72.5770796 Pascal
# Total energy: 17199.7795 Pascal² sec (energy in air: 42.9994488 Joule/m²)
# Mean power (intensity) in air: 13.1685812 Watt/m² = 131.2 dB
# Standard deviation in channel 1: 72.5773316 Pascal
#
# Something wrong
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [0]
# predict: [0]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [1]
# predict: [0]
# predict: [0]

# %%
a = [(1,2),(3,4),(5,6)]
b, c = zip(*a)
print(b)
# Out:
# (1, 3, 5)
